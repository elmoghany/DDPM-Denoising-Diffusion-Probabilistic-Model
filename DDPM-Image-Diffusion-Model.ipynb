# %% [markdown]
# - generate  64×64 animal images by training a DDPM using the AFHQ dataset
# - training
#     - -> python train.py
# - Sampling
#     - python sampling.py --ckpt_path ${CKPT_PATH} --save_dir ${SAVE_DIR_PATH}
#     - sample images and save a checkpoint every args.log_interval
# - FID
#     - python dataset.py # to constuct eval directory.
#     - python fid/measure_fid.py @GT_IMG_DIR @ GEN_IMG_DIR

# %% [markdown]
# # Libraries

# %%
import os
import sys

from itertools import chain
from multiprocessing.pool import Pool
from pathlib import Path
import argparse
import json
from datetime import datetime
from PIL import Image

from typing import Optional, Union

import numpy as np
import math
from scipy import linalg

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import init

from torchvision import transforms
from torchvision import models
from torchvision.transforms.functional import to_pil_image
import torchvision.transforms as transforms

from tqdm import tqdm
from dotmap import DotMap
from pytorch_lightning import seed_everything

import matplotlib
import matplotlib.pyplot as plt
matplotlib.use("Agg")

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
from torch.nn import DataParallel

# %% [markdown]
# # Datasets

# %%
def listdir(dname):
    fnames = list(
        chain(
            *[
                list(Path(dname).rglob("*." + ext))
                for ext in ["png", "jpg", "jpeg", "JPG"]
            ]
        )
    )
    return fnames

def tensor_to_pil_image(x: torch.Tensor, single_image=False):
    """
    x: [B,C,H,W]
    """
    if x.ndim == 3:
        x = x.unsqueeze(0)
        single_image = True

    x = (x * 0.5 + 0.5).clamp(0, 1).detach().cpu().permute(0, 2, 3, 1).numpy()
    images = (x * 255).round().astype("uint8")
    images = [Image.fromarray(image) for image in images]
    if single_image:
        return images[0]
    return images

def get_data_iterator(iterable):
    """Allows training with DataLoaders in a single infinite loop:
    for i, data in enumerate(inf_generator(train_loader)):
    """
    iterator = iterable.__iter__()
    while True:
        try:
            yield iterator.__next__()
        except StopIteration:
            iterator = iterable.__iter__()

# %%
class AFHQDataset(torch.utils.data.Dataset):
    def __init__(
        self, root: str, split: str, transform=None, max_num_images_per_cat=-1, label_offset=1
    ):
        super().__init__()
        self.root = root
        self.split = split
        self.transform = transform
        self.max_num_images_per_cat = max_num_images_per_cat
        self.label_offset = label_offset

        categories = os.listdir(os.path.join(root, split))
        self.num_classes = len(categories)

        fnames, labels = [], []
        for idx, cat in enumerate(sorted(categories)):
            category_dir = os.path.join(root, split, cat)
            cat_fnames = listdir(category_dir)
            cat_fnames = sorted(cat_fnames)
            if self.max_num_images_per_cat > 0:
                cat_fnames = cat_fnames[: self.max_num_images_per_cat]
            fnames += cat_fnames
            labels += [idx + label_offset] * len(cat_fnames)  # label 0 is for null class.

        self.fnames = fnames
        self.labels = labels

    def __getitem__(self, idx):
        img = Image.open(self.fnames[idx]).convert("RGB")
        label = self.labels[idx]
        assert label >= self.label_offset
        if self.transform is not None:
            img = self.transform(img)

        return img, label

    def __len__(self):
        return len(self.labels)

# %%
class AFHQDataModule(object):
    def __init__(
        self,
        root: str = "data",
        batch_size: int = 32,
        num_workers: int = 4,
        max_num_images_per_cat: int = 1000,
        image_resolution: int = 64,
        label_offset=1,
        transform=None
    ):
        self.root = root
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.afhq_root = os.path.join(root, "afhq")
        self.max_num_images_per_cat = max_num_images_per_cat
        self.image_resolution = image_resolution
        self.label_offset = label_offset
        self.transform = transform

        if not os.path.exists(self.afhq_root):
            print(f"{self.afhq_root} is empty. Downloading AFHQ dataset...")
            self._download_dataset()

        self._set_dataset()

    def _set_dataset(self):
        if self.transform is None:
            self.transform = transforms.Compose(
                [
                    transforms.Resize((self.image_resolution, self.image_resolution)),
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                ]
            )
        self.train_ds = AFHQDataset(
            self.afhq_root,
            "train",
            self.transform,
            max_num_images_per_cat=self.max_num_images_per_cat,
            label_offset=self.label_offset
        )
        self.val_ds = AFHQDataset(
            self.afhq_root,
            "val",
            self.transform,
            max_num_images_per_cat=self.max_num_images_per_cat,
            label_offset=self.label_offset,
        )

        self.num_classes = self.train_ds.num_classes

    def _download_dataset(self):
        URL = "https://www.dropbox.com/s/t9l9o3vsx2jai3z/afhq.zip?dl=0"
        ZIP_FILE = f"./{self.root}/afhq.zip"
        os.system(f"mkdir -p {self.root}")
        os.system(f"wget -N {URL} -O {ZIP_FILE}")
        os.system(f"unzip {ZIP_FILE} -d {self.root}")
        os.system(f"rm {ZIP_FILE}")

    def train_dataloader(self):
        return torch.utils.data.DataLoader(
            self.train_ds,
            batch_size=self.batch_size,
            num_workers=self.num_workers,
            shuffle=True,
            drop_last=True,
        )

    def val_dataloader(self):
        return torch.utils.data.DataLoader(
            self.val_ds,
            batch_size=self.batch_size,
            num_workers=self.num_workers,
            shuffle=False,
            drop_last=False,
        )
    

if __name__ == "__main__":
    data_module = AFHQDataModule("data", 32, 4, -1, 64, 1)

    eval_dir = Path(data_module.afhq_root) / "eval"
    eval_dir.mkdir(exist_ok=True)
    def func(path):
        fn = path.name
        cmd = f"cp {path} {eval_dir / fn}"
        os.system(cmd)
        img = Image.open(str(eval_dir / fn))
        img = img.resize((64,64))
        img.save(str(eval_dir / fn))
        print(fn)

    with Pool(8) as pool:
        pool.map(func, data_module.val_ds.fnames)

    print(f"Constructed eval dir at {eval_dir}")
# Out:
# pixabay_cat_001607.jpgpixabay_cat_002862.jpgflickr_cat_000008.jpg
#
#
# flickr_cat_000437.jpgpixabay_cat_000989.jpg
# pixabay_cat_000070.jpgpixabay_cat_000540.jpgpixabay_cat_002241.jpg
# pixabay_cat_001612.jpg
#
#
# flickr_cat_000011.jpg
# pixabay_cat_002865.jpg
#
# flickr_cat_000441.jpg
# pixabay_cat_000990.jpgpixabay_cat_001632.jpg
#
# flickr_cat_000016.jpg
# pixabay_cat_002871.jpgflickr_cat_000446.jpg
#
# pixabay_cat_000542.jpgpixabay_cat_002256.jpg
#
# pixabay_cat_000076.jpgpixabay_cat_001003.jpgpixabay_cat_001635.jpg
#
#
# flickr_cat_000495.jpg
# flickr_cat_000056.jpg
# pixabay_cat_002873.jpg
# pixabay_cat_000573.jpgpixabay_cat_002267.jpg
#
# pixabay_cat_001018.jpgflickr_cat_000514.jpg
#
# pixabay_cat_001643.jpg
# flickr_cat_000076.jpg
# pixabay_cat_002883.jpg
# pixabay_cat_000081.jpgflickr_cat_000522.jpg
#
# pixabay_cat_001029.jpgpixabay_cat_000582.jpg
#
# pixabay_cat_002269.jpgpixabay_cat_001653.jpgflickr_cat_000080.jpg
#
#
# pixabay_cat_002890.jpgflickr_cat_000526.jpg
#
# pixabay_cat_000592.jpgpixabay_cat_001040.jpg
#
# flickr_cat_000096.jpg
# flickr_cat_000529.jpgpixabay_cat_001665.jpgpixabay_cat_000096.jpgpixabay_cat_002298.jpg
#
#
#
# pixabay_cat_002905.jpg
# pixabay_cat_000615.jpgpixabay_cat_001055.jpg
#
# flickr_cat_000108.jpg
# flickr_cat_000534.jpg
# pixabay_cat_001672.jpg
# pixabay_cat_002307.jpgpixabay_cat_000099.jpgpixabay_cat_002922.jpg
#
#
# pixabay_cat_001080.jpgpixabay_cat_000623.jpg
# flickr_cat_000123.jpg
#
# flickr_cat_000535.jpg
# pixabay_cat_000108.jpg
# pixabay_cat_001687.jpgpixabay_cat_002927.jpgpixabay_cat_002310.jpg
#
#
# pixabay_cat_001081.jpgflickr_cat_000136.jpg
# pixabay_cat_000629.jpg
#
# flickr_cat_000536.jpg
# pixabay_cat_000117.jpg
# pixabay_cat_002928.jpgpixabay_cat_002316.jpgpixabay_cat_001690.jpg
#
#
# pixabay_cat_001084.jpg
# flickr_cat_000152.jpg
# pixabay_cat_000636.jpg
# flickr_cat_000554.jpgpixabay_cat_000126.jpg
#
# pixabay_cat_002973.jpg
# pixabay_cat_001093.jpgflickr_cat_000162.jpgpixabay_cat_002338.jpg
#
# pixabay_cat_001699.jpg
# pixabay_cat_000637.jpg
#
# pixabay_cat_000147.jpgflickr_cat_000557.jpg
#
# pixabay_cat_002986.jpg
# flickr_cat_000165.jpg
# pixabay_cat_001098.jpgpixabay_cat_001724.jpg
#
# pixabay_cat_000151.jpgpixabay_cat_002341.jpg
#
# pixabay_cat_000651.jpgflickr_cat_000560.jpgpixabay_cat_002989.jpg
#
#
# flickr_cat_000174.jpg
# pixabay_cat_001727.jpgpixabay_cat_001099.jpg
#
# pixabay_cat_000165.jpg
# flickr_cat_000570.jpgpixabay_cat_002990.jpg
# pixabay_cat_002347.jpgflickr_cat_000175.jpg
#
# pixabay_cat_000663.jpg
#
# pixabay_cat_001105.jpg
# pixabay_cat_001729.jpgpixabay_cat_000169.jpg
#
# flickr_cat_000575.jpg
# pixabay_cat_002997.jpgflickr_cat_000176.jpg
#
# pixabay_cat_001143.jpgpixabay_cat_002379.jpg
#
# pixabay_cat_000666.jpg
# pixabay_cat_000178.jpgpixabay_cat_001786.jpg
# flickr_cat_000585.jpg
#
# flickr_cat_000177.jpgpixabay_cat_001144.jpg
#
# pixabay_cat_003000.jpgpixabay_cat_002398.jpg
#
# pixabay_cat_000668.jpgpixabay_cat_000181.jpg
#
# pixabay_cat_001811.jpgflickr_cat_000592.jpg
#
# flickr_cat_000180.jpg
# pixabay_cat_001179.jpg
# pixabay_cat_003016.jpg
# pixabay_cat_000190.jpgpixabay_cat_002410.jpg
# pixabay_cat_001860.jpg
# flickr_cat_000599.jpgpixabay_cat_000696.jpg
#
#
# flickr_cat_000182.jpg
# pixabay_cat_001195.jpg
# pixabay_cat_003033.jpgpixabay_cat_001891.jpgpixabay_cat_000202.jpg
# flickr_cat_000608.jpg
#
# pixabay_cat_002435.jpg
#
# flickr_cat_000183.jpgpixabay_cat_000700.jpg
#
# pixabay_cat_001196.jpg
# pixabay_cat_000231.jpgpixabay_cat_003038.jpgpixabay_cat_001917.jpg
# flickr_cat_000184.jpg
#
# pixabay_cat_000708.jpg
#
# pixabay_cat_001205.jpg
# pixabay_cat_002438.jpgflickr_cat_000610.jpg
#
# pixabay_cat_000730.jpgpixabay_cat_001938.jpgpixabay_cat_003046.jpgflickr_cat_000191.jpg
# pixabay_cat_000241.jpg
#
#
#
# pixabay_cat_001212.jpg
# pixabay_cat_002441.jpgflickr_cat_000614.jpg
#
# pixabay_cat_003048.jpgpixabay_cat_001951.jpgflickr_cat_000208.jpgpixabay_cat_000248.jpg
#
#
#
# pixabay_cat_000735.jpg
# pixabay_cat_001269.jpg
# pixabay_cat_002452.jpgpixabay_cat_001974.jpgflickr_cat_000216.jpgflickr_cat_000628.jpg
# pixabay_cat_003079.jpg
#
#
#
# pixabay_cat_000276.jpg
# pixabay_cat_000743.jpgpixabay_cat_001272.jpg
#
# pixabay_cat_001985.jpgpixabay_cat_003117.jpg
# flickr_cat_000226.jpgflickr_cat_000629.jpg
# pixabay_cat_002462.jpg
# pixabay_cat_000291.jpg
#
#
# pixabay_cat_001286.jpg
# pixabay_cat_000751.jpg
# pixabay_cat_001992.jpgpixabay_cat_002464.jpg
# pixabay_cat_003130.jpgflickr_cat_000230.jpg
# pixabay_cat_000296.jpg
#
# flickr_cat_000635.jpgpixabay_cat_001287.jpg
#
#
# pixabay_cat_000755.jpg
# pixabay_cat_001996.jpg
# pixabay_cat_002467.jpgflickr_cat_000232.jpgpixabay_cat_003134.jpg
# flickr_cat_000637.jpgpixabay_cat_001309.jpgpixabay_cat_000299.jpg
#
#
#
#
# pixabay_cat_001997.jpgpixabay_cat_000756.jpg
#
# flickr_cat_000653.jpgpixabay_cat_002472.jpgpixabay_cat_001323.jpg
# pixabay_cat_003150.jpg
# flickr_cat_000233.jpgpixabay_cat_000302.jpg
#
#
#
# pixabay_cat_002009.jpg
# pixabay_cat_002488.jpgpixabay_cat_000760.jpg
# flickr_cat_000656.jpg
# flickr_cat_000236.jpg
# pixabay_cat_003165.jpgpixabay_cat_000314.jpg
# pixabay_cat_001342.jpg
#
#
# pixabay_cat_002037.jpg
# pixabay_cat_002510.jpg
# flickr_cat_000676.jpgflickr_cat_000238.jpg
#
# pixabay_cat_000791.jpg
# pixabay_cat_001348.jpg
# pixabay_cat_000315.jpgpixabay_cat_003187.jpg
#
# pixabay_cat_002543.jpgpixabay_cat_002064.jpg
#
# flickr_cat_000688.jpg
# flickr_cat_000253.jpg
# pixabay_cat_000801.jpg
# pixabay_cat_001359.jpg
# pixabay_cat_002552.jpg
# pixabay_cat_002075.jpgflickr_cat_000709.jpg
#
# pixabay_cat_000325.jpgflickr_cat_000265.jpgpixabay_cat_003197.jpg
#
#
# pixabay_cat_000803.jpg
# pixabay_cat_002559.jpgpixabay_cat_001365.jpg
#
# pixabay_cat_002081.jpgflickr_cat_000714.jpg
#
# pixabay_cat_000339.jpg
# pixabay_cat_003201.jpgflickr_cat_000283.jpgpixabay_cat_002582.jpg
#
#
# pixabay_cat_000812.jpgflickr_cat_000746.jpg
#
# pixabay_cat_001367.jpgpixabay_cat_002090.jpg
#
# pixabay_cat_000343.jpg
# flickr_cat_000747.jpgflickr_cat_000287.jpg
# pixabay_cat_002640.jpg
#
# pixabay_cat_003204.jpgpixabay_cat_000829.jpg
#
# pixabay_cat_002117.jpgpixabay_cat_001371.jpg
#
# pixabay_cat_000353.jpg
# flickr_cat_000751.jpg
# pixabay_cat_002650.jpg
# pixabay_cat_000831.jpgpixabay_cat_002126.jpg
# flickr_cat_000292.jpg
#
# pixabay_cat_001385.jpgpixabay_cat_003210.jpg
#
# pixabay_cat_000355.jpgflickr_cat_000759.jpg
#
# pixabay_cat_002661.jpg
# pixabay_cat_000833.jpg
# pixabay_cat_002129.jpg
# pixabay_cat_001390.jpg
# flickr_cat_000311.jpg
# pixabay_cat_000380.jpgflickr_cat_000761.jpgpixabay_cat_003211.jpg
#
# pixabay_cat_002662.jpg
#
# pixabay_cat_000840.jpgpixabay_cat_002133.jpg
#
# pixabay_cat_001405.jpg
# flickr_cat_000314.jpg
# pixabay_cat_000390.jpgflickr_cat_000766.jpgpixabay_cat_003212.jpg
#
#
# pixabay_cat_002686.jpgpixabay_cat_002138.jpg
#
# pixabay_cat_001437.jpgpixabay_cat_000842.jpg
#
# flickr_cat_000320.jpg
# pixabay_cat_003218.jpgflickr_cat_000769.jpg
# pixabay_cat_000392.jpgpixabay_cat_002694.jpg
# pixabay_cat_002140.jpg
#
#
# pixabay_cat_000844.jpgpixabay_cat_001455.jpg
#
# flickr_cat_000341.jpgpixabay_cat_003253.jpg
#
# pixabay_cat_002696.jpgflickr_cat_000802.jpgpixabay_cat_000403.jpg
# pixabay_cat_002149.jpg
#
# pixabay_cat_001457.jpg
#
# pixabay_cat_000847.jpg
# pixabay_cat_003313.jpg
# flickr_cat_000350.jpgpixabay_cat_002702.jpg
# pixabay_cat_000417.jpg
# flickr_cat_000814.jpgpixabay_cat_002155.jpg
#
#
# pixabay_cat_001460.jpgpixabay_cat_000861.jpg
#
# pixabay_cat_003341.jpgpixabay_cat_002712.jpg
# flickr_cat_000816.jpg
# flickr_cat_000351.jpg
# pixabay_cat_001464.jpg
# pixabay_cat_000440.jpg
#
# pixabay_cat_002156.jpg
# pixabay_cat_000867.jpg
# pixabay_cat_003356.jpg
# pixabay_cat_000007.jpgpixabay_cat_002724.jpg
# flickr_cat_000368.jpg
#
# pixabay_cat_001465.jpgpixabay_cat_000441.jpgpixabay_cat_002184.jpg
#
#
# pixabay_cat_000876.jpg
# pixabay_cat_003357.jpg
# pixabay_cat_000010.jpgflickr_cat_000372.jpg
#
# pixabay_cat_002749.jpg
# pixabay_cat_002198.jpgpixabay_cat_001479.jpg
#
# pixabay_cat_000459.jpgpixabay_cat_003358.jpgpixabay_cat_000889.jpg
#
#
# pixabay_cat_000037.jpg
# flickr_cat_000377.jpgpixabay_cat_002773.jpg
#
# pixabay_cat_001503.jpgpixabay_cat_002201.jpg
# pixabay_cat_003359.jpg
# pixabay_cat_000468.jpg
#
# pixabay_cat_000890.jpgpixabay_cat_000040.jpg
#
# pixabay_cat_002776.jpgflickr_cat_000387.jpg
#
# pixabay_cat_003361.jpgpixabay_cat_000491.jpgpixabay_cat_001536.jpg
# pixabay_cat_000051.jpg
#
#
# pixabay_cat_002205.jpg
# pixabay_cat_000893.jpgflickr_cat_000418.jpg
# pixabay_cat_002798.jpg
#
# pixabay_cat_003392.jpg
# pixabay_cat_001562.jpgpixabay_cat_003440.jpg
# pixabay_cat_000492.jpg
#
# flickr_cat_000419.jpg
# pixabay_cat_002212.jpgpixabay_cat_002807.jpg
#
# pixabay_cat_003413.jpgpixabay_cat_000901.jpg
#
# pixabay_cat_001599.jpgpixabay_cat_003455.jpg
#
# pixabay_cat_000504.jpg
# pixabay_cat_003931.jpgpixabay_cat_002232.jpg
#
# pixabay_cat_002823.jpg
# pixabay_cat_003464.jpgpixabay_cat_003417.jpgpixabay_cat_000929.jpg
#
#
# pixabay_cat_004543.jpgpixabay_cat_000514.jpg
#
# flickr_dog_000205.jpg
# pixabay_cat_003964.jpg
# pixabay_cat_003432.jpgpixabay_cat_003472.jpg
#
# pixabay_cat_002831.jpg
# pixabay_cat_000935.jpgpixabay_cat_004548.jpg
#
# pixabay_cat_000518.jpg
# flickr_dog_000212.jpg
# pixabay_cat_003977.jpgpixabay_cat_003483.jpg
#
# flickr_dog_000675.jpg
# pixabay_cat_000968.jpg
# pixabay_cat_004562.jpgpixabay_cat_002839.jpg
#
# flickr_dog_000216.jpgpixabay_cat_003986.jpgpixabay_cat_000531.jpg
#
# pixabay_cat_003486.jpg
#
# flickr_dog_000687.jpg
# pixabay_cat_000980.jpgpixabay_cat_004584.jpg
#
# flickr_dog_000217.jpg
# pixabay_cat_002860.jpg
# flickr_dog_000694.jpgpixabay_cat_004011.jpg
#
# pixabay_cat_003503.jpgpixabay_cat_000535.jpg
#
# pixabay_cat_004586.jpgpixabay_cat_000988.jpg
#
# flickr_dog_000224.jpg
# flickr_dog_000695.jpgpixabay_cat_004019.jpg
#
# pixabay_cat_003512.jpg
# pixabay_cat_004595.jpg
# flickr_dog_001072.jpgflickr_dog_000245.jpg
#
# pixabay_dog_000373.jpgpixabay_dog_000764.jpg
#
# flickr_dog_000706.jpg
# pixabay_cat_004029.jpg
# pixabay_cat_003524.jpg
# pixabay_cat_004596.jpgflickr_dog_000246.jpg
# flickr_dog_001085.jpg
#
# pixabay_dog_000382.jpgflickr_dog_000715.jpg
#
# pixabay_dog_000776.jpg
# pixabay_cat_004039.jpgpixabay_cat_003529.jpg
# pixabay_cat_004601.jpg
# flickr_dog_000252.jpg
#
# flickr_dog_001094.jpg
# flickr_dog_000717.jpgpixabay_dog_000393.jpg
#
# pixabay_dog_000790.jpg
# pixabay_cat_003556.jpgpixabay_cat_004602.jpgflickr_dog_000254.jpg
#
#
# pixabay_cat_004044.jpgflickr_dog_001100.jpg
#
# flickr_dog_000720.jpgpixabay_dog_000395.jpg
#
# pixabay_dog_000791.jpg
# pixabay_cat_003562.jpg
# flickr_dog_000258.jpgpixabay_cat_004616.jpg
#
# flickr_dog_000737.jpg
# flickr_dog_001120.jpgpixabay_cat_004063.jpgpixabay_dog_000409.jpg
#
#
# pixabay_dog_000794.jpgpixabay_cat_003568.jpg
# pixabay_cat_004625.jpg
#
# flickr_dog_000298.jpg
# flickr_dog_000757.jpg
# pixabay_cat_004092.jpg
# pixabay_cat_003577.jpgpixabay_dog_000799.jpg
# flickr_dog_001122.jpgpixabay_dog_000410.jpg
# pixabay_cat_004635.jpg
# flickr_dog_000313.jpg
#
#
# flickr_dog_000772.jpg
# pixabay_cat_004102.jpg
# pixabay_cat_003582.jpgpixabay_dog_000816.jpgpixabay_cat_004636.jpgpixabay_dog_000442.jpg
#
#
# flickr_dog_000317.jpg
# flickr_dog_000774.jpgflickr_dog_001173.jpg
#
#
# pixabay_cat_004104.jpg
# pixabay_dog_000818.jpgpixabay_cat_004652.jpgpixabay_cat_003595.jpg
#
# flickr_dog_000781.jpg
#
# flickr_dog_000332.jpg
# pixabay_dog_000452.jpgflickr_dog_001177.jpg
#
# pixabay_cat_004146.jpg
# pixabay_dog_000826.jpgflickr_dog_000782.jpg
# pixabay_cat_003610.jpg
# pixabay_cat_004655.jpg
#
# flickr_dog_000334.jpg
# pixabay_cat_004166.jpg
# pixabay_dog_000453.jpgpixabay_dog_000841.jpgflickr_dog_000785.jpg
#
# pixabay_dog_000009.jpg
#
# flickr_dog_000373.jpgpixabay_cat_003613.jpgpixabay_cat_004662.jpg
#
#
# pixabay_cat_004167.jpg
# pixabay_cat_003615.jpg
# pixabay_dog_000845.jpgflickr_dog_000795.jpgpixabay_dog_000454.jpg
#
#
# flickr_dog_000380.jpgpixabay_dog_000017.jpg
# pixabay_cat_004663.jpg
#
# pixabay_cat_004171.jpg
# pixabay_dog_000848.jpgpixabay_cat_003686.jpg
# flickr_dog_000806.jpg
#
# pixabay_dog_000455.jpg
# flickr_dog_000382.jpg
# pixabay_cat_004178.jpg
# pixabay_cat_004685.jpgpixabay_dog_000039.jpg
#
# pixabay_dog_000875.jpgpixabay_cat_003688.jpg
#
# flickr_dog_000812.jpg
# pixabay_dog_000471.jpgflickr_dog_000425.jpg
#
# pixabay_cat_004179.jpg
# pixabay_cat_004693.jpg
# pixabay_dog_000044.jpg
# pixabay_dog_000890.jpgpixabay_cat_003701.jpg
#
# flickr_dog_000814.jpgflickr_dog_000452.jpg
# pixabay_dog_000473.jpgpixabay_cat_004188.jpg
#
#
# pixabay_cat_004759.jpg
# pixabay_dog_000045.jpg
# pixabay_cat_003706.jpgpixabay_dog_000910.jpg
# flickr_dog_000823.jpg
# flickr_dog_000454.jpg
#
# pixabay_cat_004189.jpgpixabay_dog_000480.jpg
# pixabay_cat_004765.jpg
#
# pixabay_cat_003712.jpgpixabay_dog_000061.jpg
#
# pixabay_dog_000917.jpg
# flickr_dog_000827.jpgflickr_dog_000467.jpg
#
# pixabay_cat_004217.jpgpixabay_cat_004766.jpgpixabay_dog_000482.jpg
#
#
# pixabay_dog_000081.jpgpixabay_cat_003721.jpg
#
# pixabay_dog_000935.jpg
# flickr_dog_000835.jpgflickr_dog_000468.jpgpixabay_cat_004231.jpg
# pixabay_cat_004782.jpg
#
#
# pixabay_dog_000484.jpg
# pixabay_dog_000086.jpgpixabay_cat_003723.jpg
#
# pixabay_dog_000939.jpg
# flickr_dog_000836.jpgpixabay_cat_004783.jpgflickr_dog_000489.jpg
#
# pixabay_cat_004237.jpg
#
# pixabay_dog_000490.jpg
# pixabay_dog_000114.jpgpixabay_cat_003734.jpg
#
# pixabay_dog_000956.jpg
# pixabay_cat_004784.jpg
# flickr_dog_000491.jpgpixabay_cat_004256.jpgflickr_dog_000846.jpg
#
#
# pixabay_dog_000491.jpg
# pixabay_dog_000971.jpgpixabay_dog_000121.jpg
# pixabay_cat_003742.jpg
#
# pixabay_cat_004793.jpgflickr_dog_000495.jpg
# pixabay_cat_004297.jpgflickr_dog_000849.jpg
#
#
# pixabay_dog_000494.jpg
# pixabay_dog_000982.jpgpixabay_dog_000135.jpg
#
# pixabay_cat_003743.jpg
# flickr_dog_000521.jpgpixabay_cat_004808.jpg
# flickr_dog_000854.jpg
# pixabay_cat_004303.jpg
#
# pixabay_dog_001014.jpgpixabay_dog_000499.jpg
#
# pixabay_dog_000140.jpgpixabay_cat_003748.jpg
#
# flickr_dog_000538.jpgpixabay_cat_004816.jpgflickr_dog_000856.jpg
#
#
# pixabay_cat_004311.jpg
# pixabay_dog_001025.jpgpixabay_dog_000500.jpg
#
# pixabay_dog_000152.jpg
# pixabay_cat_004826.jpgflickr_dog_000545.jpgpixabay_cat_003753.jpgflickr_dog_000896.jpg
#
#
#
# pixabay_cat_004334.jpg
# pixabay_dog_000504.jpg
# pixabay_dog_001031.jpg
# pixabay_dog_000166.jpg
# pixabay_cat_004832.jpg
# pixabay_cat_003755.jpg
# flickr_dog_000553.jpgflickr_dog_000918.jpg
# pixabay_cat_004337.jpg
# pixabay_dog_000507.jpg
#
# pixabay_dog_001038.jpg
# pixabay_dog_000176.jpg
# flickr_dog_000043.jpg
# pixabay_cat_003773.jpgflickr_dog_000565.jpgflickr_dog_000934.jpg
#
# pixabay_dog_000508.jpg
# pixabay_cat_004343.jpg
#
# pixabay_dog_001043.jpg
# flickr_dog_000045.jpgpixabay_dog_000185.jpg
#
# flickr_dog_000567.jpg
# pixabay_cat_003794.jpg
# pixabay_cat_004358.jpg
# flickr_dog_000946.jpgpixabay_dog_000521.jpg
# pixabay_dog_001059.jpg
#
# flickr_dog_000054.jpg
# pixabay_dog_000186.jpg
# flickr_dog_000569.jpgpixabay_cat_003804.jpg
#
# pixabay_cat_004373.jpg
# pixabay_dog_001069.jpg
# flickr_dog_000059.jpgpixabay_dog_000534.jpgflickr_dog_000949.jpg
#
#
# pixabay_dog_000201.jpgpixabay_cat_003811.jpg
#
# flickr_dog_000572.jpg
# pixabay_cat_004379.jpgpixabay_dog_001073.jpg
#
# flickr_dog_000060.jpg
# pixabay_dog_000550.jpg
# pixabay_cat_003820.jpgflickr_dog_000961.jpgpixabay_dog_000206.jpg
#
#
# flickr_dog_000576.jpg
# pixabay_dog_001081.jpg
# flickr_dog_000079.jpgpixabay_cat_004415.jpg
#
# flickr_dog_000972.jpgpixabay_dog_000564.jpgpixabay_dog_000227.jpg
# pixabay_cat_003842.jpg
#
#
# flickr_dog_000580.jpg
# flickr_dog_000094.jpg
# pixabay_dog_001082.jpg
# pixabay_cat_004421.jpgpixabay_dog_000238.jpg
#
# pixabay_cat_003848.jpg
# flickr_dog_000596.jpgpixabay_dog_000569.jpgflickr_dog_000997.jpg
#
#
# flickr_dog_000104.jpg
# pixabay_dog_001083.jpgpixabay_dog_000239.jpg
#
# pixabay_cat_004422.jpg
# pixabay_cat_003874.jpg
# flickr_dog_000610.jpgflickr_dog_000111.jpg
#
# pixabay_dog_001085.jpgpixabay_dog_000582.jpg
# pixabay_dog_000241.jpgflickr_dog_000999.jpg
#
#
# pixabay_cat_004434.jpg
# pixabay_cat_003878.jpg
# flickr_dog_000116.jpg
# flickr_dog_000619.jpgpixabay_dog_001098.jpg
#
# pixabay_dog_000265.jpgflickr_dog_001002.jpgpixabay_dog_000599.jpg
#
#
# pixabay_cat_004461.jpg
# flickr_dog_000141.jpg
# pixabay_cat_003890.jpgflickr_dog_000625.jpgpixabay_dog_001121.jpg
#
# pixabay_dog_000271.jpg
#
# flickr_dog_001007.jpgpixabay_dog_000600.jpg
# flickr_dog_000157.jpg
# pixabay_cat_004480.jpg
#
# flickr_dog_000626.jpgpixabay_cat_003896.jpgpixabay_dog_001145.jpgpixabay_dog_000277.jpg
#
#
#
# flickr_dog_001012.jpgpixabay_dog_000607.jpg
#
# flickr_dog_000160.jpg
# pixabay_cat_004482.jpg
# pixabay_dog_001153.jpg
# pixabay_dog_000278.jpgflickr_dog_000629.jpgpixabay_cat_003901.jpg
#
#
# flickr_dog_000174.jpg
# pixabay_dog_000611.jpgflickr_dog_001021.jpg
# pixabay_cat_004484.jpg
#
# pixabay_dog_001156.jpg
# flickr_dog_000640.jpgpixabay_dog_000298.jpg
#
# pixabay_cat_003909.jpg
# flickr_dog_000176.jpg
# pixabay_dog_001171.jpgpixabay_dog_000617.jpg
# pixabay_cat_004505.jpgflickr_dog_001038.jpg
#
#
# flickr_dog_000642.jpgpixabay_dog_000301.jpg
#
# pixabay_cat_003911.jpgflickr_dog_000193.jpg
#
# pixabay_dog_001192.jpgpixabay_cat_004510.jpg
#
# flickr_dog_000654.jpgpixabay_dog_000618.jpgflickr_dog_001041.jpg
#
# pixabay_dog_000307.jpg
#
# flickr_dog_000198.jpg
# pixabay_cat_003924.jpg
# pixabay_dog_001195.jpgpixabay_dog_000640.jpg
# pixabay_cat_004513.jpg
# pixabay_dog_000311.jpg
# flickr_dog_001042.jpg
# flickr_dog_000658.jpgpixabay_dog_001236.jpg
#
#
# pixabay_dog_001860.jpg
# pixabay_dog_000646.jpg
# pixabay_dog_001196.jpg
# pixabay_dog_000321.jpgpixabay_cat_004520.jpg
# flickr_dog_000673.jpg
#
# pixabay_dog_001880.jpgpixabay_dog_001244.jpg
# flickr_dog_001052.jpg
#
# pixabay_dog_000647.jpg
# pixabay_cat_004542.jpg
# pixabay_dog_001199.jpgpixabay_dog_002329.jpg
# pixabay_dog_000322.jpg
# pixabay_dog_001898.jpg
#
# pixabay_dog_001290.jpgflickr_dog_001055.jpgpixabay_dog_000672.jpg
#
#
# pixabay_dog_002862.jpg
# pixabay_dog_002363.jpg
# pixabay_dog_001205.jpgpixabay_dog_001901.jpg
#
# pixabay_dog_000327.jpgpixabay_dog_001296.jpg
# pixabay_dog_000691.jpg
#
# flickr_dog_001067.jpg
# pixabay_dog_002877.jpgpixabay_dog_002366.jpg
#
# pixabay_dog_001211.jpgpixabay_dog_001341.jpgpixabay_dog_001911.jpg
#
# pixabay_dog_000330.jpg
#
# pixabay_dog_000713.jpg
# flickr_dog_001071.jpg
# pixabay_dog_002383.jpgpixabay_dog_002895.jpg
#
# pixabay_dog_001350.jpg
# pixabay_dog_001231.jpg
# pixabay_dog_000338.jpgpixabay_dog_001912.jpg
#
# pixabay_dog_000715.jpg
# pixabay_dog_002390.jpgpixabay_dog_002897.jpg
# pixabay_dog_003398.jpg
# pixabay_dog_001352.jpg
#
# pixabay_dog_000723.jpgpixabay_dog_001234.jpgpixabay_dog_000341.jpg
#
#
# pixabay_dog_001919.jpgpixabay_dog_002402.jpg
# pixabay_dog_001356.jpg
# pixabay_dog_002900.jpg
#
# pixabay_dog_003406.jpg
# pixabay_dog_000724.jpgpixabay_dog_000351.jpg
# pixabay_dog_003943.jpgpixabay_dog_001358.jpgpixabay_dog_002418.jpg
# pixabay_dog_001924.jpg
#
#
# pixabay_dog_002909.jpg
#
# pixabay_dog_003410.jpg
# pixabay_dog_003945.jpgpixabay_dog_001361.jpgpixabay_dog_000737.jpg
#
# pixabay_dog_002930.jpgpixabay_dog_000357.jpg
# pixabay_dog_002423.jpg
# pixabay_dog_001928.jpg
#
#
# pixabay_dog_003421.jpg
# pixabay_dog_003975.jpgpixabay_dog_001370.jpg
# pixabay_dog_000738.jpg
# pixabay_dog_002949.jpg
#
# pixabay_dog_002441.jpgpixabay_dog_001931.jpg
#
# flickr_wild_000314.jpg
# pixabay_dog_003448.jpg
# pixabay_dog_001374.jpg
# flickr_wild_000731.jpgpixabay_dog_001962.jpg
#
# pixabay_dog_003980.jpgpixabay_dog_002447.jpgpixabay_dog_002956.jpg
#
#
# flickr_wild_000354.jpg
# pixabay_dog_003449.jpgpixabay_dog_001375.jpg
#
# flickr_wild_000738.jpgpixabay_dog_001965.jpg
#
# pixabay_dog_002453.jpg
# pixabay_dog_003989.jpgpixabay_dog_002957.jpg
#
# pixabay_dog_001381.jpg
# flickr_wild_000360.jpg
# pixabay_dog_003465.jpg
# flickr_wild_000752.jpgpixabay_dog_002492.jpg
# pixabay_dog_001971.jpg
#
# pixabay_dog_001383.jpg
# pixabay_dog_003990.jpgflickr_wild_000361.jpgpixabay_dog_002979.jpg
#
#
# pixabay_dog_003468.jpg
# pixabay_dog_002515.jpg
# pixabay_dog_001978.jpgflickr_wild_000771.jpgpixabay_dog_001431.jpg
#
#
# flickr_wild_000373.jpg
# pixabay_dog_003478.jpgpixabay_dog_003997.jpg
#
# pixabay_dog_003008.jpg
# pixabay_dog_002520.jpg
# pixabay_dog_001443.jpgpixabay_dog_001985.jpg
#
# flickr_wild_000814.jpgflickr_wild_000375.jpg
#
# pixabay_dog_003480.jpg
# pixabay_dog_002526.jpgpixabay_dog_004000.jpg
# pixabay_dog_003009.jpg
# pixabay_dog_001445.jpg
#
# pixabay_dog_002017.jpgflickr_wild_000379.jpg
#
# pixabay_dog_003489.jpgflickr_wild_000833.jpg
#
# pixabay_dog_004005.jpgpixabay_dog_002544.jpg
# pixabay_dog_003068.jpgpixabay_dog_001449.jpg
#
#
# pixabay_dog_002030.jpgflickr_wild_000382.jpg
#
# pixabay_dog_003493.jpg
# flickr_wild_000836.jpg
# pixabay_dog_004006.jpgpixabay_dog_002548.jpg
# pixabay_dog_001463.jpg
# pixabay_dog_003069.jpg
#
# pixabay_dog_002034.jpgflickr_wild_000397.jpg
#
# pixabay_dog_003502.jpg
# flickr_wild_000855.jpgpixabay_dog_004016.jpg
# pixabay_dog_001497.jpg
# pixabay_dog_002556.jpg
#
# pixabay_dog_003092.jpg
# flickr_wild_000406.jpgpixabay_dog_002035.jpg
# pixabay_dog_003505.jpg
#
# flickr_wild_000870.jpgpixabay_dog_004057.jpg
#
# pixabay_dog_001506.jpgpixabay_dog_002566.jpg
#
# flickr_wild_000409.jpgpixabay_dog_003095.jpg
#
# pixabay_dog_003521.jpgpixabay_dog_002044.jpg
#
# flickr_wild_000898.jpg
# pixabay_dog_001522.jpgpixabay_dog_004058.jpg
# pixabay_dog_002567.jpg
#
# flickr_wild_000411.jpg
# pixabay_dog_003528.jpgpixabay_dog_003105.jpg
#
# pixabay_dog_002066.jpg
# flickr_wild_000923.jpgpixabay_dog_001523.jpg
#
# flickr_wild_000004.jpg
# pixabay_dog_002586.jpg
# flickr_wild_000418.jpgpixabay_dog_003535.jpg
#
# pixabay_dog_002070.jpgpixabay_dog_003122.jpg
# flickr_wild_000929.jpg
# pixabay_dog_001530.jpg
#
# flickr_wild_000012.jpg
# pixabay_dog_002597.jpg
# pixabay_dog_003539.jpg
# pixabay_dog_002113.jpgflickr_wild_000419.jpg
#
# pixabay_dog_003123.jpgpixabay_dog_001536.jpgflickr_wild_000932.jpg
#
#
# flickr_wild_000017.jpg
# pixabay_dog_002610.jpg
# pixabay_dog_003543.jpgpixabay_dog_002119.jpg
#
# pixabay_dog_001561.jpg
# flickr_wild_000942.jpgflickr_wild_000420.jpg
#
# pixabay_dog_003136.jpg
# pixabay_dog_002616.jpgflickr_wild_000038.jpg
#
# pixabay_dog_003552.jpgpixabay_dog_002122.jpg
#
# pixabay_dog_001567.jpg
# flickr_wild_000946.jpg
# flickr_wild_000428.jpgpixabay_dog_003149.jpg
#
# pixabay_dog_002625.jpgflickr_wild_000039.jpgpixabay_dog_003574.jpg
# pixabay_dog_002126.jpg
#
#
# pixabay_dog_001568.jpg
# flickr_wild_000988.jpg
# flickr_wild_000432.jpg
# pixabay_dog_003591.jpgpixabay_dog_003165.jpgpixabay_dog_002144.jpg
# pixabay_dog_002647.jpg
#
#
# pixabay_dog_001569.jpgflickr_wild_000040.jpg
#
# flickr_wild_001003.jpg
# flickr_wild_000441.jpgpixabay_dog_002148.jpgpixabay_dog_003637.jpg
#
#
# pixabay_dog_002652.jpgpixabay_dog_001570.jpgpixabay_dog_003185.jpg
#
#
# flickr_wild_000046.jpg
# flickr_wild_001037.jpg
# pixabay_dog_002151.jpgpixabay_dog_003658.jpg
#
# flickr_wild_000470.jpgpixabay_dog_001575.jpg
# pixabay_dog_002670.jpg
# pixabay_dog_003190.jpg
#
# flickr_wild_000053.jpg
# flickr_wild_001043.jpgpixabay_dog_003667.jpg
#
# pixabay_dog_002152.jpgpixabay_dog_001609.jpgflickr_wild_000498.jpg
#
# pixabay_dog_002680.jpg
# pixabay_dog_003192.jpg
# flickr_wild_000061.jpg
#
# pixabay_dog_003669.jpg
# flickr_wild_001050.jpg
# pixabay_dog_003197.jpgflickr_wild_000504.jpgflickr_wild_000063.jpgpixabay_dog_002699.jpg
# pixabay_dog_001647.jpgpixabay_dog_002157.jpg
#
#
#
#
# pixabay_dog_003672.jpg
# flickr_wild_001053.jpg
# flickr_wild_000064.jpgflickr_wild_000506.jpgpixabay_dog_001651.jpg
#
#
# pixabay_dog_003223.jpgpixabay_dog_002700.jpg
#
# pixabay_dog_003703.jpgpixabay_dog_002158.jpg
#
# flickr_wild_001088.jpg
# flickr_wild_000075.jpgflickr_wild_000517.jpg
#
# pixabay_dog_001654.jpg
# pixabay_dog_002739.jpgpixabay_dog_003709.jpg
#
# pixabay_dog_003230.jpg
# pixabay_dog_002176.jpg
# flickr_wild_001094.jpg
# flickr_wild_000090.jpg
# flickr_wild_000521.jpg
# pixabay_dog_003710.jpgpixabay_dog_001687.jpgpixabay_dog_002743.jpgpixabay_dog_003250.jpg
#
#
#
# pixabay_dog_002196.jpg
# flickr_wild_001096.jpgflickr_wild_000099.jpg
#
# pixabay_dog_002756.jpg
# pixabay_dog_003720.jpgpixabay_dog_003251.jpgflickr_wild_000524.jpgpixabay_dog_001689.jpg
#
#
#
# pixabay_dog_002199.jpg
# flickr_wild_000125.jpg
# flickr_wild_001112.jpg
# pixabay_dog_002766.jpg
# pixabay_dog_003261.jpgpixabay_dog_003726.jpg
#
# pixabay_dog_001700.jpgflickr_wild_000526.jpg
#
# pixabay_dog_002223.jpgflickr_wild_000128.jpg
#
# flickr_wild_001113.jpgpixabay_dog_002774.jpg
#
# pixabay_dog_003265.jpgpixabay_dog_003728.jpg
#
# flickr_wild_000527.jpg
# pixabay_dog_001705.jpgflickr_wild_000129.jpg
#
# pixabay_dog_002234.jpgflickr_wild_001114.jpg
#
# pixabay_dog_002782.jpgpixabay_dog_003741.jpg
# pixabay_dog_003293.jpg
#
# flickr_wild_000535.jpg
# pixabay_dog_002238.jpgflickr_wild_000133.jpgpixabay_dog_001735.jpgflickr_wild_001119.jpg
#
#
#
# pixabay_dog_003307.jpgpixabay_dog_003747.jpgpixabay_dog_002785.jpg
#
#
# flickr_wild_000557.jpg
# pixabay_dog_002239.jpgflickr_wild_001129.jpg
# flickr_wild_000135.jpg
# pixabay_dog_001799.jpg
#
# pixabay_dog_002786.jpgpixabay_dog_003751.jpgpixabay_dog_003309.jpg
#
#
# flickr_wild_000560.jpg
# pixabay_dog_002245.jpgflickr_wild_001137.jpg
#
# flickr_wild_000144.jpg
# pixabay_dog_002792.jpgpixabay_dog_003766.jpgpixabay_dog_001800.jpg
#
#
# flickr_wild_000568.jpgpixabay_dog_003323.jpg
#
# pixabay_dog_002279.jpg
# flickr_wild_001152.jpg
# flickr_wild_000147.jpgpixabay_dog_003767.jpg
#
# pixabay_dog_002799.jpgpixabay_dog_001806.jpg
# flickr_wild_000599.jpg
#
# pixabay_dog_003334.jpg
# flickr_wild_001177.jpgpixabay_dog_002297.jpg
#
# pixabay_dog_003775.jpgflickr_wild_000149.jpg
#
# pixabay_dog_002801.jpgpixabay_dog_001816.jpg
#
# flickr_wild_000603.jpgpixabay_dog_003335.jpg
#
# flickr_wild_001205.jpg
# pixabay_dog_002304.jpg
# pixabay_dog_003776.jpg
# flickr_wild_000187.jpgpixabay_dog_002829.jpg
# pixabay_dog_001835.jpg
#
# pixabay_dog_003345.jpg
# flickr_wild_000607.jpg
# flickr_wild_001211.jpg
# pixabay_dog_002307.jpg
# pixabay_dog_003856.jpgpixabay_dog_002839.jpg
#
# flickr_wild_000192.jpg
# pixabay_dog_003351.jpgpixabay_dog_001854.jpg
#
# flickr_wild_001217.jpgflickr_wild_000609.jpg
#
# pixabay_dog_002313.jpgpixabay_dog_003887.jpg
#
# flickr_wild_000194.jpgpixabay_dog_002841.jpg
#
# pixabay_dog_003355.jpgflickr_wild_001308.jpg
# flickr_wild_001219.jpg
#
# flickr_wild_000628.jpg
# pixabay_dog_002317.jpg
# pixabay_dog_003891.jpgpixabay_dog_002854.jpg
#
# flickr_wild_000206.jpgpixabay_dog_003366.jpg
# flickr_wild_001312.jpg
# flickr_wild_001223.jpg
#
# flickr_wild_000629.jpg
# pixabay_dog_002323.jpg
# pixabay_dog_002857.jpgpixabay_dog_003914.jpg
#
# pixabay_dog_003372.jpgflickr_wild_000211.jpg
# flickr_wild_001319.jpg
# flickr_wild_001230.jpg
#
# flickr_wild_000632.jpg
# flickr_wild_001825.jpg
# flickr_wild_002272.jpgpixabay_dog_003922.jpg
#
# pixabay_dog_003376.jpg
# flickr_wild_000225.jpgflickr_wild_001237.jpgflickr_wild_001321.jpg
#
#
# flickr_wild_001839.jpgflickr_wild_000634.jpg
#
# flickr_wild_002273.jpgpixabay_dog_003937.jpg
#
# pixabay_dog_003379.jpg
# flickr_wild_001250.jpgflickr_wild_000252.jpg
# flickr_wild_001325.jpg
#
# flickr_wild_001843.jpg
# flickr_wild_000662.jpgflickr_wild_002276.jpg
#
# pixabay_dog_003942.jpg
# pixabay_dog_003383.jpg
# flickr_wild_001251.jpg
# flickr_wild_001846.jpgflickr_wild_001327.jpgflickr_wild_000257.jpg
#
#
# flickr_wild_000685.jpg
# flickr_wild_002295.jpg
# flickr_wild_002801.jpg
# flickr_wild_003208.jpg
# flickr_wild_001253.jpgflickr_wild_001862.jpg
#
# flickr_wild_001329.jpgflickr_wild_000267.jpg
#
# flickr_wild_000690.jpg
# flickr_wild_002312.jpg
# flickr_wild_002809.jpg
# flickr_wild_001258.jpg
# flickr_wild_003209.jpgflickr_wild_001874.jpg
#
# flickr_wild_001330.jpgflickr_wild_000286.jpg
#
# flickr_wild_000699.jpg
# flickr_wild_002829.jpgflickr_wild_002314.jpg
# flickr_wild_001275.jpg
# flickr_wild_001875.jpg
# flickr_wild_003230.jpg
#
# flickr_wild_001332.jpgflickr_wild_000302.jpg
#
# flickr_wild_000700.jpgflickr_wild_002319.jpg
# flickr_wild_001286.jpg
# flickr_wild_001890.jpg
# flickr_wild_002856.jpg
#
# flickr_wild_003231.jpg
# flickr_wild_001354.jpg
# flickr_wild_000306.jpg
# flickr_wild_000711.jpgflickr_wild_002325.jpg
#
# flickr_wild_001297.jpgflickr_wild_001892.jpgflickr_wild_002867.jpg
#
#
# flickr_wild_003234.jpg
# flickr_wild_001383.jpg
# flickr_wild_003718.jpg
# flickr_wild_000712.jpg
# flickr_wild_001927.jpgflickr_wild_002871.jpg
# flickr_wild_002336.jpgflickr_wild_001299.jpg
#
#
# flickr_wild_003238.jpgflickr_wild_001397.jpg
#
# flickr_wild_003734.jpg
# flickr_wild_000729.jpg
# flickr_wild_001938.jpg
# flickr_wild_002364.jpgpixabay_wild_000281.jpg
#
# flickr_wild_002874.jpgflickr_wild_003246.jpg
#
# flickr_wild_001398.jpgflickr_wild_003761.jpg
#
# pixabay_wild_000751.jpgflickr_wild_001941.jpg
#
# pixabay_wild_000298.jpg
# flickr_wild_002393.jpgflickr_wild_002886.jpg
#
# flickr_wild_003263.jpg
# flickr_wild_003767.jpgflickr_wild_001402.jpg
#
# pixabay_wild_000762.jpgflickr_wild_001945.jpg
#
# pixabay_wild_000326.jpg
# flickr_wild_002410.jpgflickr_wild_002896.jpg
#
# flickr_wild_003324.jpg
# flickr_wild_003768.jpgflickr_wild_001432.jpg
#
# pixabay_wild_000776.jpg
# flickr_wild_001953.jpgpixabay_wild_000343.jpg
#
# flickr_wild_002914.jpg
# flickr_wild_002433.jpgflickr_wild_003773.jpgflickr_wild_003326.jpg
#
#
# flickr_wild_001434.jpgpixabay_wild_000791.jpg
#
# flickr_wild_001986.jpg
# pixabay_wild_000349.jpg
# flickr_wild_002924.jpg
# flickr_wild_003777.jpgflickr_wild_003331.jpgflickr_wild_002445.jpg
#
#
# pixabay_wild_000794.jpgflickr_wild_001436.jpg
#
# flickr_wild_001988.jpgpixabay_wild_000354.jpg
#
# flickr_wild_002926.jpg
# flickr_wild_003335.jpgflickr_wild_003779.jpg
#
# flickr_wild_002461.jpgflickr_wild_001448.jpg
#
# flickr_wild_001995.jpgpixabay_wild_000801.jpg
#
# flickr_wild_002929.jpg
# pixabay_wild_000356.jpg
# flickr_wild_003780.jpgflickr_wild_003346.jpg
#
# flickr_wild_001457.jpg
# flickr_wild_002016.jpgflickr_wild_002486.jpg
#
# pixabay_wild_000838.jpgflickr_wild_002933.jpg
#
# flickr_wild_003786.jpgflickr_wild_003350.jpg
# pixabay_wild_000361.jpg
#
# flickr_wild_001460.jpg
# flickr_wild_002020.jpg
# flickr_wild_002936.jpg
# flickr_wild_003791.jpgflickr_wild_002500.jpgpixabay_wild_000840.jpg
#
# flickr_wild_003355.jpg
#
# flickr_wild_001469.jpg
# pixabay_wild_000363.jpg
# flickr_wild_002942.jpgflickr_wild_002022.jpg
#
# flickr_wild_003796.jpg
# flickr_wild_003357.jpgflickr_wild_001475.jpg
# flickr_wild_002501.jpg
# pixabay_wild_000855.jpg
#
# pixabay_wild_000381.jpgflickr_wild_002946.jpg
#
# flickr_wild_002030.jpgflickr_wild_003808.jpg
#
# flickr_wild_001508.jpg
# pixabay_wild_000856.jpg
# flickr_wild_003361.jpgflickr_wild_002508.jpg
# flickr_wild_002948.jpg
#
# flickr_wild_003817.jpgpixabay_wild_000393.jpgflickr_wild_002032.jpg
#
#
# flickr_wild_001517.jpg
# pixabay_wild_000863.jpg
# flickr_wild_003367.jpg
# flickr_wild_002955.jpg
# flickr_wild_002517.jpgflickr_wild_003823.jpg
#
# flickr_wild_002036.jpgpixabay_wild_000404.jpgflickr_wild_001545.jpg
#
#
# pixabay_wild_000864.jpgflickr_wild_003380.jpg
#
# flickr_wild_002956.jpg
# flickr_wild_003827.jpgflickr_wild_001547.jpgflickr_wild_002043.jpgpixabay_wild_000414.jpgflickr_wild_002520.jpg
#
#
#
#
# pixabay_wild_000866.jpgflickr_wild_003386.jpg
#
# flickr_wild_002971.jpg
# flickr_wild_003831.jpgflickr_wild_001552.jpgflickr_wild_002053.jpgpixabay_wild_000418.jpg
#
#
#
# pixabay_wild_000877.jpgflickr_wild_002524.jpgflickr_wild_003388.jpg
#
#
# flickr_wild_002994.jpg
# flickr_wild_001563.jpgflickr_wild_002055.jpg
# pixabay_wild_000420.jpgflickr_wild_003840.jpg
#
# flickr_wild_002542.jpgpixabay_wild_000885.jpg
# flickr_wild_003389.jpg
#
#
# flickr_wild_002998.jpg
# flickr_wild_001576.jpgpixabay_wild_000423.jpg
#
# flickr_wild_003842.jpgflickr_wild_003392.jpgpixabay_wild_000920.jpg
# flickr_wild_002058.jpg
#
# flickr_wild_003000.jpgflickr_wild_002544.jpg
#
#
# flickr_wild_001583.jpg
# flickr_wild_003849.jpg
# pixabay_wild_000926.jpgpixabay_wild_000428.jpgflickr_wild_002545.jpgflickr_wild_003399.jpg
#
#
#
# flickr_wild_003026.jpg
# flickr_wild_002064.jpg
# flickr_wild_001587.jpgflickr_wild_003854.jpg
#
# pixabay_wild_000434.jpgflickr_wild_003408.jpgpixabay_wild_000940.jpg
# flickr_wild_003060.jpg
#
# flickr_wild_002553.jpg
#
# flickr_wild_002081.jpg
# flickr_wild_003882.jpgflickr_wild_001598.jpg
#
# pixabay_wild_000955.jpgflickr_wild_003061.jpgflickr_wild_003421.jpgpixabay_wild_000449.jpg
#
#
#
# flickr_wild_002558.jpg
# flickr_wild_002092.jpgflickr_wild_003918.jpgflickr_wild_001602.jpg
#
#
# flickr_wild_003436.jpgflickr_wild_003065.jpgpixabay_wild_000958.jpg
#
#
# pixabay_wild_000470.jpg
# flickr_wild_002562.jpg
# flickr_wild_002093.jpgflickr_wild_001606.jpg
#
# flickr_wild_003924.jpg
# flickr_wild_003449.jpg
# flickr_wild_003067.jpgpixabay_wild_000965.jpg
# pixabay_wild_000478.jpg
#
# flickr_wild_001619.jpg
# flickr_wild_002565.jpgflickr_wild_003465.jpg
#
# flickr_wild_003927.jpgflickr_wild_002112.jpg
#
# flickr_wild_003073.jpg
# pixabay_wild_000966.jpgpixabay_wild_000493.jpg
#
# flickr_wild_001625.jpg
# flickr_wild_003475.jpgflickr_wild_002571.jpgflickr_wild_003943.jpg
#
#
# flickr_wild_003085.jpgpixabay_wild_000522.jpgflickr_wild_002124.jpg
#
#
# pixabay_wild_000972.jpgflickr_wild_001627.jpg
#
# flickr_wild_002578.jpgflickr_wild_003498.jpg
#
# flickr_wild_003947.jpgpixabay_wild_000535.jpgflickr_wild_003120.jpg
#
#
# flickr_wild_002138.jpg
# flickr_wild_001634.jpg
# pixabay_wild_000988.jpg
# flickr_wild_002603.jpg
# pixabay_wild_000536.jpgflickr_wild_003501.jpgflickr_wild_003130.jpgflickr_wild_003963.jpg
#
#
# flickr_wild_002139.jpg
# flickr_wild_001641.jpg
#
# pixabay_wild_000994.jpg
# flickr_wild_002614.jpgflickr_wild_003506.jpgflickr_wild_003137.jpg
#
# flickr_wild_002145.jpg
# pixabay_wild_000555.jpg
# flickr_wild_003969.jpg
# flickr_wild_001658.jpg
#
# pixabay_wild_001001.jpg
# flickr_wild_003513.jpg
# flickr_wild_003145.jpgflickr_wild_002159.jpg
# flickr_wild_002637.jpg
# flickr_wild_001683.jpg
#
# pixabay_wild_000558.jpgflickr_wild_003970.jpg
#
# pixabay_wild_001010.jpgflickr_wild_003519.jpg
#
# flickr_wild_002166.jpgflickr_wild_003148.jpg
#
# flickr_wild_001692.jpg
# flickr_wild_003981.jpgflickr_wild_002676.jpg
#
# pixabay_wild_000559.jpg
# pixabay_wild_001028.jpgflickr_wild_003543.jpg
#
# flickr_wild_002182.jpg
# flickr_wild_003149.jpg
# flickr_wild_001711.jpgpixabay_wild_000017.jpg
#
# flickr_wild_002686.jpgpixabay_wild_001043.jpg
#
# pixabay_wild_000564.jpgflickr_wild_002185.jpgflickr_wild_003571.jpg
#
#
# flickr_wild_001732.jpgflickr_wild_003156.jpgpixabay_wild_000022.jpg
#
#
# pixabay_wild_001058.jpg
# flickr_wild_003586.jpgflickr_wild_002190.jpg
#
# flickr_wild_002694.jpgpixabay_wild_000574.jpg
#
# pixabay_wild_000025.jpg
# flickr_wild_001737.jpgflickr_wild_003169.jpg
#
# pixabay_wild_001082.jpg
# flickr_wild_002210.jpgflickr_wild_003587.jpg
# pixabay_wild_000584.jpg
#
# pixabay_wild_000034.jpg
# flickr_wild_001793.jpgflickr_wild_002709.jpg
# flickr_wild_003173.jpg
# pixabay_wild_001093.jpg
#
# flickr_wild_002217.jpgpixabay_wild_000594.jpg
# flickr_wild_003603.jpg
#
# pixabay_wild_000046.jpgflickr_wild_001815.jpgflickr_wild_002713.jpg
#
#
# pixabay_wild_001094.jpgflickr_wild_003183.jpg
#
# flickr_wild_003615.jpgflickr_wild_002226.jpg
# pixabay_wild_000047.jpgpixabay_wild_000598.jpg
#
#
# flickr_wild_002714.jpgpixabay_wild_001112.jpg
#
# flickr_wild_003186.jpg
# flickr_wild_003617.jpg
# flickr_wild_002726.jpgpixabay_wild_000105.jpgpixabay_wild_001115.jpgflickr_wild_002239.jpg
#
#
# pixabay_wild_000604.jpg
#
# flickr_wild_003190.jpg
# flickr_wild_003643.jpg
# pixabay_wild_001128.jpg
# flickr_wild_002733.jpgpixabay_wild_000106.jpg
#
# flickr_wild_002250.jpgpixabay_wild_000613.jpgflickr_wild_003192.jpg
#
#
# flickr_wild_003656.jpg
# pixabay_wild_001133.jpg
# pixabay_wild_000155.jpg
# flickr_wild_002747.jpg
# flickr_wild_003193.jpg
# flickr_wild_002259.jpgflickr_wild_003669.jpgpixabay_wild_000629.jpg
#
#
# pixabay_wild_001134.jpg
# pixabay_wild_000183.jpg
# flickr_wild_002754.jpg
# flickr_wild_003197.jpg
# pixabay_wild_000637.jpgflickr_wild_003710.jpg
#
# pixabay_wild_001165.jpg
# pixabay_wild_000185.jpg
# flickr_wild_002775.jpg
# flickr_wild_003207.jpgpixabay_wild_000639.jpg
# flickr_wild_003712.jpg
#
# pixabay_wild_001170.jpg
# pixabay_wild_000190.jpgflickr_wild_002784.jpg
#
# pixabay_wild_000650.jpg
# flickr_wild_002785.jpgpixabay_wild_001184.jpg
#
# pixabay_wild_000217.jpgpixabay_wild_000654.jpg
#
# pixabay_wild_001192.jpgpixabay_wild_000664.jpg
#
# pixabay_wild_000265.jpg
# pixabay_wild_000680.jpgpixabay_wild_001224.jpg
#
# pixabay_wild_000267.jpg
# pixabay_wild_000683.jpg
# pixabay_wild_000274.jpg
# pixabay_wild_000684.jpg
# pixabay_wild_000719.jpg
# pixabay_wild_000732.jpg
# pixabay_wild_000745.jpg
# Constructed eval dir at data/afhq/eval

# %% [markdown]
# # Swish

# %%
class Swish(nn.Module):
    def forward(self, x):
        return x * torch.sigmoid(x)

# %% [markdown]
# # Down Sample

# %%
class DownSample(nn.Module):
    def __init__(self, in_ch):
        super().__init__()
        self.main = nn.Conv2d(in_ch, in_ch, 3, stride=2, padding=1)
        self.initialize()

    def initialize(self):
        init.xavier_uniform_(self.main.weight)
        init.zeros_(self.main.bias)

    def forward(self, x, temb):
        x = self.main(x)
        return x

# %% [markdown]
# # Up Sample

# %%
class UpSample(nn.Module):
    def __init__(self, in_ch):
        super().__init__()
        self.main = nn.Conv2d(in_ch, in_ch, 3, stride=1, padding=1)
        self.initialize()

    def initialize(self):
        init.xavier_uniform_(self.main.weight)
        init.zeros_(self.main.bias)

    def forward(self, x, temb):
        _, _, H, W = x.shape
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        x = self.main(x)
        return x

# %% [markdown]
# # Attention Block

# %%
class AttnBlock(nn.Module):
    def __init__(self, in_ch):
        super().__init__()
        self.group_norm = nn.GroupNorm(32, in_ch)
        self.proj_q = nn.Conv2d(in_ch, in_ch, 1, stride=1, padding=0)
        self.proj_k = nn.Conv2d(in_ch, in_ch, 1, stride=1, padding=0)
        self.proj_v = nn.Conv2d(in_ch, in_ch, 1, stride=1, padding=0)
        self.proj = nn.Conv2d(in_ch, in_ch, 1, stride=1, padding=0)
        self.initialize()

    def initialize(self):
        for module in [self.proj_q, self.proj_k, self.proj_v, self.proj]:
            init.xavier_uniform_(module.weight)
            init.zeros_(module.bias)
        init.xavier_uniform_(self.proj.weight, gain=1e-5)

    def forward(self, x):
        B, C, H, W = x.shape
        h = self.group_norm(x)
        q = self.proj_q(h)
        k = self.proj_k(h)
        v = self.proj_v(h)

        q = q.permute(0, 2, 3, 1).view(B, H * W, C)
        k = k.view(B, C, H * W)
        w = torch.bmm(q, k) * (int(C) ** (-0.5))
        assert list(w.shape) == [B, H * W, H * W]
        w = F.softmax(w, dim=-1)

        v = v.permute(0, 2, 3, 1).view(B, H * W, C)
        h = torch.bmm(w, v)
        assert list(h.shape) == [B, H * W, C]
        h = h.view(B, H, W, C).permute(0, 3, 1, 2)
        h = self.proj(h)

        return x + h

# %% [markdown]
# # Residual Block

# %%
class ResBlock(nn.Module):
    def __init__(self, in_ch, out_ch, tdim, dropout, attn=False):
        super().__init__()
        self.block1 = nn.Sequential(
            nn.GroupNorm(32, in_ch),
            Swish(),
            nn.Conv2d(in_ch, out_ch, 3, stride=1, padding=1),
        )
        self.temb_proj = nn.Sequential(
            Swish(),
            nn.Linear(tdim, out_ch),
        )
        self.block2 = nn.Sequential(
            nn.GroupNorm(32, out_ch),
            Swish(),
            nn.Dropout(dropout),
            nn.Conv2d(out_ch, out_ch, 3, stride=1, padding=1),
        )
        if in_ch != out_ch:
            self.shortcut = nn.Conv2d(in_ch, out_ch, 1, stride=1, padding=0)
        else:
            self.shortcut = nn.Identity()
        if attn:
            self.attn = AttnBlock(out_ch)
        else:
            self.attn = nn.Identity()
        self.initialize()

    def initialize(self):
        for module in self.modules():
            if isinstance(module, (nn.Conv2d, nn.Linear)):
                init.xavier_uniform_(module.weight)
                init.zeros_(module.bias)
        init.xavier_uniform_(self.block2[-1].weight, gain=1e-5)

    def forward(self, x, temb):
        h = self.block1(x)
        h += self.temb_proj(temb)[:, :, None, None]
        h = self.block2(h)

        h = h + self.shortcut(x)
        h = self.attn(h)
        return h

# %% [markdown]
# # Time Embedding

# %%
class TimeEmbedding(nn.Module):
    def __init__(self, hidden_size, frequency_embedding_size=256):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Linear(frequency_embedding_size, hidden_size, bias=True),
            nn.SiLU(),
            nn.Linear(hidden_size, hidden_size, bias=True),
        )
        self.frequency_embedding_size = frequency_embedding_size

    @staticmethod
    def timestep_embedding(t, dim, max_period=10000):
        """
        Create sinusoidal timestep embeddings.
        :param t: a 1-D Tensor of N indices, one per batch element.
                          These may be fractional.
        :param dim: the dimension of the output.
        :param max_period: controls the minimum frequency of the embeddings.
        :return: an (N, D) Tensor of positional embeddings.
        """
        # https://github.com/openai/glide-text2im/blob/main/glide_text2im/nn.py
        half = dim // 2
        freqs = torch.exp(
            -math.log(max_period)
            * torch.arange(start=0, end=half, dtype=torch.float32)
            / half
        ).to(device=t.device)
        args = t[:, None].float() * freqs[None]
        embedding = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
        if dim % 2:
            embedding = torch.cat(
                [embedding, torch.zeros_like(embedding[:, :1])], dim=-1
            )
        return embedding

    def forward(self, t):
        if t.ndim == 0:
            t = t.unsqueeze(-1)
        t_freq = self.timestep_embedding(t, self.frequency_embedding_size)
        t_emb = self.mlp(t_freq)
        return t_emb

# %% [markdown]
# # U-Net

# %%
class UNet(nn.Module):
    def __init__(self, T=1000, image_resolution=64, ch=128, ch_mult=[1,2,2,2], attn=[1], num_res_blocks=4, dropout=0.1, use_cfg=False, cfg_dropout=0.1, num_classes=None):
        super().__init__()
        self.image_resolution = image_resolution
        assert all([i < len(ch_mult) for i in attn]), 'attn index out of bound'
        tdim = ch * 4
        # self.time_embedding = TimeEmbedding(T, ch, tdim)
        self.time_embedding = TimeEmbedding(tdim)

        # classifier-free guidance
        self.use_cfg = use_cfg
        self.cfg_dropout = cfg_dropout
        if use_cfg:
            assert num_classes is not None
            cdim = tdim
            self.class_embedding = nn.Embedding(num_classes+1, cdim)

        self.head = nn.Conv2d(3, ch, kernel_size=3, stride=1, padding=1)
        self.downblocks = nn.ModuleList()
        chs = [ch]  # record output channel when dowmsample for upsample
        now_ch = ch
        for i, mult in enumerate(ch_mult):
            out_ch = ch * mult
            for _ in range(num_res_blocks):
                self.downblocks.append(ResBlock(
                    in_ch=now_ch, out_ch=out_ch, tdim=tdim,
                    dropout=dropout, attn=(i in attn)))
                now_ch = out_ch
                chs.append(now_ch)
            if i != len(ch_mult) - 1:
                self.downblocks.append(DownSample(now_ch))
                chs.append(now_ch)

        self.middleblocks = nn.ModuleList([
            ResBlock(now_ch, now_ch, tdim, dropout, attn=True),
            ResBlock(now_ch, now_ch, tdim, dropout, attn=False),
        ])

        self.upblocks = nn.ModuleList()
        for i, mult in reversed(list(enumerate(ch_mult))):
            out_ch = ch * mult
            for _ in range(num_res_blocks + 1):
                self.upblocks.append(ResBlock(
                    in_ch=chs.pop() + now_ch, out_ch=out_ch, tdim=tdim,
                    dropout=dropout, attn=(i in attn)))
                now_ch = out_ch
            if i != 0:
                self.upblocks.append(UpSample(now_ch))
        assert len(chs) == 0

        self.tail = nn.Sequential(
            nn.GroupNorm(32, now_ch),
            Swish(),
            nn.Conv2d(now_ch, 3, 3, stride=1, padding=1)
        )
        self.initialize()

    def initialize(self):
        init.xavier_uniform_(self.head.weight)
        init.zeros_(self.head.bias)
        init.xavier_uniform_(self.tail[-1].weight, gain=1e-5)
        init.zeros_(self.tail[-1].bias)

    def forward(self, x, timestep, class_label=None):
        # Timestep embedding
        temb = self.time_embedding(timestep)

        if self.use_cfg and class_label is not None:
            if self.training:
                assert not torch.any(class_label == 0) # 0 for null.
                
                ######## TODO ########
                # DO NOT change the code outside this part.
                # Assignment 2. Implement random null conditioning in CFG training.
                raise NotImplementedError("TODO")
                #######################
            
            ######## TODO ########
            # DO NOT change the code outside this part.
            # Assignment 2. Implement class conditioning
            raise NotImplementedError("TODO")
            #######################

        # Downsampling
        h = self.head(x)
        hs = [h]
        for layer in self.downblocks:
            h = layer(h, temb)
            hs.append(h)
        # Middle
        for layer in self.middleblocks:
            h = layer(h, temb)
        # Upsampling
        for layer in self.upblocks:
            if isinstance(layer, ResBlock):
                h = torch.cat([h, hs.pop()], dim=1)
            h = layer(h, temb)
        h = self.tail(h)

        assert len(hs) == 0
        return h

# %% [markdown]
# # Base Scheduler

# %%
class BaseScheduler(nn.Module):
    def __init__(
        self, num_train_timesteps: int, beta_1: float, beta_T: float, mode="linear"
    ):
        super().__init__()
        self.num_train_timesteps = num_train_timesteps
        self.num_inference_timesteps = num_train_timesteps
        self.timesteps = torch.from_numpy(
            np.arange(0, self.num_train_timesteps)[::-1].copy().astype(np.int64)
        )

        if mode == "linear":
            betas = torch.linspace(beta_1, beta_T, steps=num_train_timesteps)
        elif mode == "quad":
            betas = (
                torch.linspace(beta_1**0.5, beta_T**0.5, num_train_timesteps) ** 2
            )
        else:
            raise NotImplementedError(f"{mode} is not implemented.")

        alphas = 1 - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)

        self.register_buffer("betas", betas)
        self.register_buffer("alphas", alphas)
        self.register_buffer("alphas_cumprod", alphas_cumprod)

    def uniform_sample_t(
        self, batch_size, device: Optional[torch.device] = None
    ) -> torch.IntTensor:
        """
        Uniformly sample timesteps.
        """
        ts = np.random.choice(np.arange(self.num_train_timesteps), batch_size)
        ts = torch.from_numpy(ts)
        if device is not None:
            ts = ts.to(device)
        return ts

# %% [markdown]
# # DDPM Scheduler

# %% [markdown]
# - implement the methods add_noise and step of the class DDPMScheduler
# - Refer to your implementation of the methods
#     - q_sample -> add_noise
#     - p_sample -> step
#     - compute_loss -> get_loss

# %%
class DDPMScheduler(BaseScheduler):
    def __init__(
        self,
        num_train_timesteps: int,
        beta_1: float,
        beta_T: float,
        mode="linear",
        sigma_type="small",
    ):
        super().__init__(num_train_timesteps, beta_1, beta_T, mode)
    
        # sigmas correspond to $\sigma_t$ in the DDPM paper.
        self.sigma_type = sigma_type
        if sigma_type == "small":
            # when $\sigma_t^2 = \tilde{\beta}_t$.
            alphas_cumprod_t_prev = torch.cat(
                [torch.tensor([1.0]), self.alphas_cumprod[:-1]]
            )
            sigmas = (
                (1 - alphas_cumprod_t_prev) / (1 - self.alphas_cumprod) * self.betas
            ) ** 0.5
        elif sigma_type == "large":
            # when $\sigma_t^2 = \beta_t$.
            sigmas = self.betas ** 0.5

        self.register_buffer("sigmas", sigmas)

    def step(self, x_t: torch.Tensor, t: int, eps_theta: torch.Tensor):
        """
        One step denoising function of DDPM: x_t -> x_{t-1}.

        Input:
            x_t (`torch.Tensor [B,C,H,W]`): samples at arbitrary timestep t.
            t (`int`): current timestep in a reverse process.
            eps_theta (`torch.Tensor [B,C,H,W]`): predicted noise from a learned model.
        Ouptut:
            sample_prev (`torch.Tensor [B,C,H,W]`): one step denoised sample. (= x_{t-1})
        """

        ######## TODO ########
        # DO NOT change the code outside this part.
        # Assignment 1. Implement the DDPM reverse step.        
        if isinstance(t, int):
            t = torch.tensor([t]).to(self.device)

        alpha_t = self._get_teeth(self.alphas.to(device), t)
        alpha_cumprod_t = self._get_teeth(self.alphas_cumprod.to(device), t)
        beta_t = self._get_teeth(self.betas.to(device), t).to(device)

        eps_factor = (1 - alpha_t) / (1 - alpha_cumprod_t).sqrt()
        mean = (x_t - eps_factor*eps_theta) / (alpha_t.sqrt())
        
        sigma = self._get_teeth(self.sigmas.to(device), t)
        noise = torch.randn_like(x_t).to(device)
        
        sample_prev = mean + sigma * noise

        #######################
        
        return sample_prev
    
    # https://nn.labml.ai/diffusion/ddpm/utils.html
    def _get_teeth(self, consts: torch.Tensor, t: torch.Tensor): # get t th const
        t = t.to(consts.device) 
        const = consts.gather(-1, t)
        return const.reshape(-1, 1, 1, 1)
    
    def add_noise(
        self,
        x_0: torch.Tensor,
        t: torch.IntTensor,
        eps: Optional[torch.Tensor] = None,
    ):
        """
        A forward pass of a Markov chain, i.e., q(x_t | x_0).

        Input:
            x_0 (`torch.Tensor [B,C,H,W]`): samples from a real data distribution q(x_0).
            t: (`torch.IntTensor [B]`)
            eps: (`torch.Tensor [B,C,H,W]`, optional): if None, randomly sample Gaussian noise in the function.
        Output:
            x_t: (`torch.Tensor [B,C,H,W]`): noisy samples at timestep t.
            eps: (`torch.Tensor [B,C,H,W]`): injected noise.
        """
        
        if eps is None:
            eps       = torch.randn(x_0.shape, device='cuda')

        ######## TODO ########
        # DO NOT change the code outside this part.
        # Assignment 1. Implement the DDPM forward step.
        alphas_prod_t = self._get_teeth(self.alphas_cumprod, t).to(device)
        x_t = alphas_prod_t.sqrt()*x_0 + (1-alphas_prod_t).sqrt()*eps
        #######################

        return x_t, eps

# %% [markdown]
# # Diffusion Model

# %% [markdown]
# - implement the method get_loss of the class DiffusionModule

# %%
class DiffusionModule(nn.Module):
    def __init__(self, network, var_scheduler, **kwargs):
        super().__init__()
        self.network = network
        self.var_scheduler = var_scheduler

    def get_loss(self, x0, class_label=None, noise=None):
        ######## TODO ########
        # DO NOT change the code outside this part.
        # compute noise matching loss.
        B = x0.shape[0]
        timestep = self.var_scheduler.uniform_sample_t(B, self.device)
                
        xt_pred, injected_noise = self.var_scheduler.add_noise(x0, timestep, noise)
        
        pred_noise = self.network(xt_pred, timestep)
        
        loss = F.mse_loss(pred_noise, injected_noise)
        ######################
        return loss
    
    @property
    def device(self):
        return next(self.network.parameters()).device

    @property
    def image_resolution(self):
        return self.network.image_resolution

    @torch.no_grad()
    def sample(
        self,
        batch_size,
        return_traj=False,
        class_label: Optional[torch.Tensor] = None,
        guidance_scale: Optional[float] = 1.0,
    ):
        x_T = torch.randn([batch_size, 3, self.image_resolution, self.image_resolution]).to(self.device)

        do_classifier_free_guidance = guidance_scale > 1.0

        if do_classifier_free_guidance:

            ######## TODO ########
            # Assignment 2. Implement the classifier-free guidance.
            # Specifically, given a tensor of shape (batch_size,) containing class labels,
            # create a tensor of shape (2*batch_size,) where the first half is filled with zeros (i.e., null condition).
            assert class_label is not None
            assert len(class_label) == batch_size, f"len(class_label) != batch_size. {len(class_label)} != {batch_size}"
            raise NotImplementedError("TODO")
            #######################

        traj = [x_T]
        for t in tqdm(self.var_scheduler.timesteps):
            x_t = traj[-1]
            if do_classifier_free_guidance:
                ######## TODO ########
                # Assignment 2. Implement the classifier-free guidance.
                raise NotImplementedError("TODO")
                #######################
            else:
                noise_pred = self.network(x_t, timestep=t.to(self.device))

            x_t_prev = self.var_scheduler.step(x_t, t, noise_pred)

            traj[-1] = traj[-1].cpu()
            traj.append(x_t_prev.detach())

        if return_traj:
            return traj
        else:
            return traj[-1]

    def save(self, file_path):
        hparams = {
            "network": self.network,
            "var_scheduler": self.var_scheduler,
            } 
        state_dict = self.state_dict()

        dic = {"hparams": hparams, "state_dict": state_dict}
        torch.save(dic, file_path)

    def load(self, file_path):
        dic = torch.load(file_path, map_location="cpu")
        hparams = dic["hparams"]
        state_dict = dic["state_dict"]

        self.network = hparams["network"]
        self.var_scheduler = hparams["var_scheduler"]

        self.load_state_dict(state_dict)

# %% [markdown]
# # Training

# %%
def get_current_time():
    now = datetime.now().strftime("%m-%d-%H%M%S")
    return now

args = {
    "gpu": 0,
    "batch_size": 16,
    "train_num_steps": 100000,
    "warmup_steps": 200,
    "log_interval": 200,
    "max_num_images_per_cat": 3000,
    "num_diffusion_train_timesteps": 1000,
    "beta_1": 1e-4,
    "beta_T": 0.02,
    "seed": 63,
    "image_resolution": 64,
    "sample_method": "ddpm",
    "use_cfg": False,  # Change to True if conditional training is required
    "cfg_dropout": 0.1,
}

args = DotMap(args)

def main(args):
    """config"""
    config = DotMap(args)
    config.update(vars(args))
    config.device = f"cuda:{args.gpu}"

    now = get_current_time()
    if args.use_cfg:
        save_dir = Path(f"results/cfg_diffusion-{args.sample_method}-{now}")
    else:
        save_dir = Path(f"results/diffusion-{args.sample_method}-{now}")
    save_dir.mkdir(exist_ok=True, parents=True)
    print(f"save_dir: {save_dir}")
    
    seed_everything(int(config.seed))
    # seed_everything(config.seed)

    with open(save_dir / "config.json", "w") as f:
        json.dump(config, f, indent=2)
    """######"""

    image_resolution = 64
    ds_module = AFHQDataModule(
        "./data",
        batch_size=config.batch_size,
        num_workers=4,
        max_num_images_per_cat=config.max_num_images_per_cat,
        image_resolution=image_resolution
    )

    train_dl = ds_module.train_dataloader()
    train_it = get_data_iterator(train_dl)

    # Set up the scheduler
    var_scheduler = DDPMScheduler(
        config.num_diffusion_train_timesteps,
        beta_1=config.beta_1,
        beta_T=config.beta_T,
        mode="linear",
    )

    network = UNet(
        T=config.num_diffusion_train_timesteps,
        image_resolution=image_resolution,
        ch=128,
        ch_mult=[1, 2, 2, 2],
        attn=[1],
        num_res_blocks=4,
        dropout=0.1,
        use_cfg=args.use_cfg,
        cfg_dropout=args.cfg_dropout,
        num_classes=getattr(ds_module, "num_classes", None),
    )

    ddpm = DiffusionModule(network, var_scheduler)
    #################################
    ## Parallel Compute
    ddpm = DataParallel(ddpm)
    #################################
    ddpm = ddpm.to(config.device)

    # optimizer = torch.optim.Adam(ddpm.network.parameters(), lr=2e-4)
    optimizer = torch.optim.Adam(ddpm.module.network.parameters(), lr=2e-4)
    scheduler = torch.optim.lr_scheduler.LambdaLR(
        optimizer, lr_lambda=lambda t: min((t + 1) / config.warmup_steps, 1.0)
    )

    step = 0
    losses = []
    with tqdm(initial=step, total=config.train_num_steps) as pbar:
        while step < config.train_num_steps:
            if step % config.log_interval == 0:
                ddpm.eval()
                plt.plot(losses)
                plt.savefig(f"{save_dir}/loss.png")
                plt.close()
                # samples = ddpm.sample(4, return_traj=False)
                samples = ddpm.module.sample(4, return_traj=False)
                pil_images = tensor_to_pil_image(samples)
                for i, img in enumerate(pil_images):
                    img.save(save_dir / f"step={step}-{i}.png")

                # ddpm.save(f"{save_dir}/last.ckpt")
                ddpm.module.save(f"{save_dir}/last.ckpt")
                ddpm.train()

            img, label = next(train_it)
            img, label = img.to(config.device), label.to(config.device)
            if args.use_cfg:  # Conditional, CFG training
                # loss = ddpm.get_loss(img, class_label=label)
                loss = ddpm.module.get_loss(img, class_label=label)
            else:  # Unconditional training
                # loss = ddpm.get_loss(img)
                loss = ddpm.module.get_loss(img)
            pbar.set_description(f"Loss: {loss.item():.4f}")

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            scheduler.step()
            losses.append(loss.item())

            step += 1
            pbar.update(1)

# Define a configuration dictionary

# Convert the dictionary into an object (DotMap is convenient for this)
# Run the main function
main(args)

# if __name__ == "__main__":
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--gpu", type=int, default=0)
#     parser.add_argument("--batch_size", type=int, default=16)
#     parser.add_argument(
#         "--train_num_steps",
#         type=int,
#         default=100000,
#         help="the number of model training steps.",
#     )
#     parser.add_argument("--warmup_steps", type=int, default=200)
#     parser.add_argument("--log_interval", type=int, default=200)
#     parser.add_argument(
#         "--max_num_images_per_cat",
#         type=int,
#         default=3000,
#         help="max number of images per category for AFHQ dataset",
#     )
#     parser.add_argument(
#         "--num_diffusion_train_timesteps",
#         type=int,
#         default=1000,
#         help="diffusion Markov chain num steps",
#     )
#     parser.add_argument("--beta_1", type=float, default=1e-4)
#     parser.add_argument("--beta_T", type=float, default=0.02)
#     parser.add_argument("--seed", type=int, default=63)
#     parser.add_argument("--image_resolution", type=int, default=64)
#     parser.add_argument("--sample_method", type=str, default="ddpm")
#     parser.add_argument("--use_cfg", action="store_true")
#     parser.add_argument("--cfg_dropout", type=float, default=0.1)
#     args = parser.parse_args()
#     main(args)
# Out:
# Seed set to 63
# save_dir: results/diffusion-ddpm-01-01-193058
# 100%|██████████| 1000/1000 [00:41<00:00, 24.23it/s]
# 100%|██████████| 1000/1000 [00:38<00:00, 25.65it/s]:48:43,  2.16it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.31it/s]18:14,  5.22it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.23it/s]05:04,  5.43it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.12it/s]35:39,  4.93it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.36it/s]:39:26,  4.86it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.83it/s]:49:37,  4.71it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.26it/s]:57:00,  5.53it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.23it/s]:18:01,  5.16it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.22it/s]:11:18,  4.41it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 34.08it/s]:31:19,  4.17it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.62it/s]:02:38,  4.49it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.04it/s]:08:21,  4.42it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.61it/s]:00:24,  4.50it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.48it/s]:16:39,  5.12it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.94it/s]:33:03,  4.85it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 38.87it/s]:12:30,  5.16it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 35.95it/s]:12:49,  4.32it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.92it/s]:06:17,  4.39it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.25it/s]:42:06,  4.69it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 34.05it/s]:56:55,  4.48it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.35it/s]:43:56,  4.64it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.87it/s]:26:27,  4.88it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.01it/s]:20:12,  4.97it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.34it/s]:09:57,  5.12it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.17it/s]:08:38,  5.13it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.11it/s]:17:08,  4.98it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.07it/s]:47:03,  3.87it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.16it/s]:43:21,  4.58it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.01it/s]:13:54,  5.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.45it/s]:01:14,  5.20it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.72it/s]:12:04,  5.01it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.40it/s]:14:12,  4.96it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.43it/s]:55:04,  5.28it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.32it/s]:19:35,  4.09it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.36it/s]:16:03,  4.90it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.73it/s]:16:26,  4.89it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.51it/s]:45:19,  4.47it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.40it/s]:19:37,  4.82it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.30it/s]:37:38,  4.55it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 34.29it/s]:04:13,  4.21it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.69it/s]:32:09,  4.61it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.30it/s]:59:55,  4.24it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.52it/s]:03:25,  6.26it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.57it/s]:17:59,  4.78it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.54it/s]:45:41,  4.39it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.36it/s]:26:39,  4.63it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.29it/s]:30:43,  3.86it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.38it/s]:09:26,  4.87it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.56it/s]<6:14:58,  4.01it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.66it/s]1<5:26:00,  4.60it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.39it/s]5<5:19:48,  4.68it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.35it/s]7<5:38:57,  4.41it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.46it/s]7<5:23:53,  4.60it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.45it/s]8<5:14:31,  4.73it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.26it/s]9<4:34:37,  5.40it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.54it/s]9<5:12:27,  4.74it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 37.40it/s]9<5:14:58,  4.69it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.68it/s]3<4:52:08,  5.04it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.70it/s]4<5:51:20,  4.18it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.64it/s]5<5:21:41,  4.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.27it/s]6<5:04:29,  4.81it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.69it/s]7<5:02:27,  4.83it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.02it/s]9<4:52:33,  4.98it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.44it/s]0<5:31:57,  4.38it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.00it/s]2<5:21:02,  4.52it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.23it/s]5<4:37:45,  5.21it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.18it/s]5<5:25:58,  4.43it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.14it/s]6<5:02:39,  4.76it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.10it/s]7<4:47:01,  5.01it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.01it/s]9<5:26:38,  4.39it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.75it/s]0<4:45:55,  5.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.03it/s]1<5:13:59,  4.54it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.91it/s]2<4:17:12,  5.53it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.67it/s]3<5:11:32,  4.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.20it/s]3<4:57:19,  4.76it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.83it/s]5<4:48:52,  4.89it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.20it/s]6<5:11:00,  4.53it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.13it/s]7<6:26:37,  3.64it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.94it/s]9<5:02:42,  4.64it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.22it/s]0<5:49:44,  4.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.33it/s]9<5:05:56,  4.57it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.67it/s]1<4:53:59,  4.74it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.03it/s]2<4:59:12,  4.65it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.34it/s]2<5:50:00,  3.96it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.91it/s]3<4:48:34,  4.79it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.41it/s]3<5:27:04,  4.22it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.14it/s]3<5:00:50,  4.58it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.00it/s]4<4:34:59,  4.99it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.91it/s]5<5:46:52,  3.95it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 34.15it/s]6<5:48:38,  3.92it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 38.71it/s]2<5:00:09,  4.54it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.32it/s]6<4:14:06,  5.35it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.10it/s]3<4:35:35,  4.92it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.28it/s]1<5:58:57,  3.77it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 34.33it/s]7<4:56:14,  4.56it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.14it/s]3<4:52:07,  4.61it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.90it/s]1<4:07:23,  5.43it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 34.02it/s]5<4:26:50,  5.02it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 34.18it/s]1<4:26:42,  5.01it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 35.89it/s]7<4:18:07,  5.17it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.20it/s]4<4:25:28,  5.01it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.07it/s]6<4:04:34,  5.42it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.34it/s]3<4:41:57,  4.69it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.39it/s]0<5:10:49,  4.25it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.10it/s]7<4:54:40,  4.47it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.91it/s]2<4:41:12,  4.67it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.77it/s]3<4:37:51,  4.71it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.75it/s]4<4:44:49,  4.59it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.84it/s]4<3:45:41,  5.78it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.15it/s]5<4:39:26,  4.65it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.34it/s]6<4:34:28,  4.72it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.42it/s]6<4:26:30,  4.85it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.33it/s]7<4:32:59,  4.73it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 38.49it/s]9<4:29:04,  4.78it/s]
# 100%|██████████| 1000/1000 [00:28<00:00, 34.81it/s]2<4:08:23,  5.17it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.61it/s]5<4:37:46,  4.61it/s]
# 100%|██████████| 1000/1000 [00:41<00:00, 24.13it/s]0<4:36:25,  4.62it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.39it/s]0<4:30:34,  4.71it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.36it/s]1<4:08:50,  5.10it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.91it/s]2<4:37:55,  4.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.21it/s]1<4:34:24,  4.60it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.41it/s]1<4:15:08,  4.94it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.06it/s]1<3:36:01,  5.82it/s]
# 100%|██████████| 1000/1000 [00:31<00:00, 31.77it/s]2<4:11:45,  4.98it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.44it/s]9<4:25:29,  4.71it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.91it/s]9<4:42:46,  4.41it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.93it/s]7<3:58:00,  5.22it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.10it/s]8<4:39:24,  4.44it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.55it/s]0<3:41:22,  5.59it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.54it/s]0<4:49:25,  4.26it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.04it/s]8<4:42:34,  4.35it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.53it/s]8<3:28:51,  5.87it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.39it/s]0<4:31:27,  4.51it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.40it/s]0<4:03:41,  5.01it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.81it/s]0<4:01:57,  5.03it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.41it/s]0<3:52:46,  5.21it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.34it/s]9<3:35:59,  5.60it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.53it/s]0<4:58:39,  4.04it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.69it/s]6<4:14:19,  4.73it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.27it/s]4<4:28:23,  4.47it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.66it/s]4<4:43:08,  4.23it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.74it/s]6<4:20:36,  4.58it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.41it/s]9<4:31:58,  4.38it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.52it/s]3<3:57:40,  4.99it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.19it/s]4<4:00:49,  4.91it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.39it/s]5<4:20:32,  4.53it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.39it/s]6<4:12:58,  4.65it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.57it/s]7<4:03:02,  4.83it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.30it/s]7<4:51:32,  4.01it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.77it/s]2<3:42:36,  5.24it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.28it/s]8<4:55:39,  3.93it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.07it/s]9<4:35:03,  4.22it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.30it/s]9<4:07:10,  4.68it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.39it/s]1<5:16:40,  3.64it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.57it/s]2<3:52:01,  4.96it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.56it/s]2<4:23:33,  4.35it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.56it/s]2<4:11:24,  4.55it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.53it/s]3<3:58:31,  4.78it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.68it/s]9<3:32:44,  5.34it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 38.71it/s]4<4:18:47,  4.38it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.52it/s]5<3:45:48,  5.00it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.58it/s]2<3:44:04,  5.03it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.56it/s]9<4:13:22,  4.43it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.39it/s]6<3:35:50,  5.19it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.50it/s]7<4:08:11,  4.50it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.32it/s]5<4:02:48,  4.59it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.49it/s]7<3:21:50,  5.50it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.29it/s]8<3:40:46,  5.01it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.81it/s]0<3:35:47,  5.11it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.74it/s]6<3:57:14,  4.64it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.58it/s]3<3:03:35,  5.97it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.21it/s]4<4:11:11,  4.35it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.29it/s]4<3:52:23,  4.69it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.35it/s]4<3:55:16,  4.62it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.06it/s]5<4:14:02,  4.26it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.31it/s]5<3:44:57,  4.80it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.13it/s]3<3:33:21,  5.05it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.21it/s]1<3:41:41,  4.84it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.20it/s]0<4:06:24,  4.34it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.03it/s]8<4:12:08,  4.23it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.61it/s]6<3:53:12,  4.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.89it/s]3<3:20:28,  5.29it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.55it/s]2<3:31:32,  5.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.63it/s]0<3:44:40,  4.69it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.09it/s]0<3:31:13,  4.97it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.87it/s]0<3:50:24,  4.54it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.11it/s]8<4:09:37,  4.18it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.25it/s]6<3:07:11,  5.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.23it/s]2<2:45:37,  6.26it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.10it/s]1<3:41:59,  4.65it/s]
# 100%|██████████| 1000/1000 [00:36<00:00, 27.37it/s]9<2:52:15,  5.98it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.17it/s]1<3:40:02,  4.67it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.58it/s]0<3:37:30,  4.70it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.36it/s]0<3:23:25,  5.01it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.61it/s]0<3:30:32,  4.83it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.65it/s]7<3:05:15,  5.47it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.58it/s]5<3:34:08,  4.72it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.97it/s]6<3:16:14,  5.13it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.25it/s]4<3:26:09,  4.87it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.85it/s]4<3:51:41,  4.32it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.07it/s]3<3:38:36,  4.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.80it/s]3<3:36:06,  4.60it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.89it/s]4<3:55:42,  4.20it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.45it/s]3<3:01:59,  5.42it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.15it/s]2<3:12:19,  5.11it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.70it/s]1<3:36:02,  4.54it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.51it/s]8<3:15:19,  5.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.21it/s]6<2:44:09,  5.93it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.60it/s]3<3:00:48,  5.37it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.42it/s]1<3:58:26,  4.05it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.76it/s]9<3:07:46,  5.13it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.83it/s]6<3:11:01,  5.03it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.39it/s]4<3:11:50,  4.99it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.50it/s]1<3:34:38,  4.44it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.47it/s]0<3:02:31,  5.20it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.50it/s]5<3:02:00,  5.20it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 38.76it/s]8<2:55:49,  5.37it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.53it/s]9<2:59:38,  5.23it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.64it/s]3<3:10:25,  4.92it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.99it/s]7<2:33:32,  6.08it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.88it/s]4<3:06:56,  4.97it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.42it/s]1<3:51:56,  4.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.50it/s]0<2:48:50,  5.47it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.59it/s]7<3:16:32,  4.68it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 40.00it/s]5<3:30:24,  4.36it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.13it/s]5<3:13:54,  4.71it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.29it/s]4<2:47:08,  5.44it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.21it/s]2<3:17:12,  4.60it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.63it/s]0<2:58:50,  5.05it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.72it/s]7<2:59:27,  5.02it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.51it/s]7<3:23:11,  4.41it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.54it/s]4<3:09:57,  4.70it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.51it/s]2<2:58:18,  4.99it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.49it/s]0<2:57:36,  4.99it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.50it/s]9<3:11:15,  4.62it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.56it/s]7<3:22:35,  4.34it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.28it/s]6<2:39:54,  5.48it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.24it/s]4<2:38:18,  5.52it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.81it/s]2<2:34:35,  5.63it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.86it/s]9<3:10:25,  4.55it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.78it/s]7<2:35:04,  5.57it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.05it/s]5<2:42:38,  5.29it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.49it/s]2<2:38:52,  5.39it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.84it/s]0<3:05:22,  4.60it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.79it/s]9<3:18:43,  4.28it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 37.25it/s]9<2:58:05,  4.75it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.47it/s]9<2:49:46,  4.97it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.62it/s]8<3:19:38,  4.21it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.66it/s]7<2:27:03,  5.69it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 37.88it/s]0<3:06:26,  4.47it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.53it/s]0<2:18:44,  5.98it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.41it/s]7<2:25:34,  5.68it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.59it/s]5<2:55:16,  4.70it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.07it/s]2<2:32:10,  5.39it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.47it/s]0<2:56:26,  4.63it/s]
# 100%|██████████| 1000/1000 [00:23<00:00, 41.70it/s]8<3:14:29,  4.18it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.52it/s]6<2:31:36,  5.34it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.76it/s]4<2:56:36,  4.57it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.59it/s]7<2:45:37,  4.85it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.35it/s]5<2:53:15,  4.62it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.46it/s]3<2:44:09,  4.85it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.56it/s]9<2:50:36,  4.65it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.62it/s]3<2:34:07,  5.13it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.59it/s]7<2:44:22,  4.79it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.16it/s]0<3:04:33,  4.24it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.63it/s]9<2:16:15,  5.72it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.39it/s]7<2:24:38,  5.37it/s]
# 100%|██████████| 1000/1000 [00:23<00:00, 41.71it/s]5<2:49:14,  4.57it/s]
# 100%|██████████| 1000/1000 [00:23<00:00, 42.08it/s]3<3:09:16,  4.07it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.99it/s]1<2:32:34,  5.02it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.27it/s]8<2:21:08,  5.41it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.29it/s]7<2:40:03,  4.75it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.32it/s]5<2:35:49,  4.86it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.34it/s]3<2:42:52,  4.63it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 37.70it/s]2<2:44:20,  4.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.19it/s]4<2:40:22,  4.66it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.00it/s]3<2:19:00,  5.35it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.88it/s]1<2:27:22,  5.02it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.22it/s]1<2:22:01,  5.19it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.31it/s]0<2:26:07,  5.02it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.50it/s]8<2:02:51,  5.94it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.49it/s]6<2:30:08,  4.84it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.13it/s]5<2:20:55,  5.13it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.32it/s]4<2:37:09,  4.58it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.53it/s]7<2:40:22,  4.47it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.20it/s]9<2:09:22,  5.51it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.34it/s]1<2:22:12,  4.99it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.09it/s]6<2:27:24,  4.79it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.42it/s]4<2:19:05,  5.06it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.47it/s]2<2:18:11,  5.07it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.66it/s]7<2:18:31,  5.03it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.57it/s]5<2:18:48,  4.99it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.38it/s]3<2:14:04,  5.15it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.48it/s]1<2:09:22,  5.31it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.94it/s]9<2:28:30,  4.60it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.61it/s]7<2:25:43,  4.67it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.70it/s]1<2:29:07,  4.54it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.45it/s]6<2:19:28,  4.83it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.07it/s]0<2:00:13,  5.57it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.20it/s]9<2:35:42,  4.28it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.98it/s]2<2:12:32,  5.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.80it/s]1<1:45:50,  6.24it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.13it/s]0<2:15:28,  4.85it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.63it/s]9<2:21:07,  4.63it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.09it/s]8<2:23:46,  4.52it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.90it/s]8<2:19:43,  4.63it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 37.99it/s]6<2:05:25,  5.13it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.09it/s]7<2:01:20,  5.27it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.37it/s]6<2:16:45,  4.66it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.02it/s]9<2:13:20,  4.75it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.44it/s]8<1:59:59,  5.25it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.17it/s]7<1:58:08,  5.30it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.95it/s]5<2:00:14,  5.18it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.15it/s]4<2:16:49,  4.53it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.85it/s]3<2:05:31,  4.91it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.99it/s]2<1:58:52,  5.16it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.10it/s]1<1:51:41,  5.46it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.46it/s]1<2:17:06,  4.42it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.27it/s]1<2:01:42,  4.96it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.33it/s]5<2:16:09,  4.41it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.29it/s]7<1:31:21,  6.53it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.26it/s]5<1:44:28,  5.68it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.33it/s]1<1:57:18,  5.03it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.50it/s]7<1:49:19,  5.37it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.42it/s]5<1:55:47,  5.04it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.07it/s]0<2:02:13,  4.75it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.55it/s]5<1:50:18,  5.23it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.05it/s]1<1:42:44,  5.58it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.67it/s]6<1:41:29,  5.62it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.58it/s]6<1:53:19,  5.00it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.42it/s]2<1:42:59,  5.47it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.81it/s]7<1:32:44,  6.04it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.49it/s]2<1:42:19,  5.44it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.11it/s]6<1:33:51,  5.90it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.64it/s]2<1:43:00,  5.34it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.34it/s]7<1:49:38,  4.99it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.85it/s]1<1:38:06,  5.54it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.95it/s]6<1:28:24,  6.11it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.06it/s]2<1:34:34,  5.67it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.29it/s]6<1:47:13,  4.97it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.51it/s]1<1:34:56,  5.58it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.72it/s]1<1:32:43,  5.68it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.45it/s]2<1:50:23,  4.74it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.39it/s]8<1:42:53,  5.05it/s]
# 100%|██████████| 1000/1000 [00:23<00:00, 42.32it/s]3<1:36:22,  5.36it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.68it/s]7<1:44:45,  4.90it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.51it/s]2<1:29:44,  5.68it/s]
# 100%|██████████| 1000/1000 [00:23<00:00, 42.25it/s]7<1:30:57,  5.57it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.57it/s]1<1:30:28,  5.56it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.64it/s]6<1:44:57,  4.76it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.93it/s]1<1:38:42,  5.03it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.48it/s]7<1:29:19,  5.52it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.88it/s]2<1:30:36,  5.41it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.39it/s]7<1:23:34,  5.82it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.19it/s]3<1:37:40,  4.95it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.58it/s]0<1:30:03,  5.33it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.74it/s]6<1:27:21,  5.46it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.83it/s]2<1:16:49,  6.16it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 32.80it/s]8<1:33:34,  5.02it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.18it/s]1<1:26:33,  5.39it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.85it/s]1<1:22:35,  5.61it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.49it/s]6<1:22:06,  5.60it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.87it/s]3<1:27:19,  5.23it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.57it/s]2<1:24:04,  5.39it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.53it/s]3<1:35:25,  4.72it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.46it/s]4<1:20:54,  5.52it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.50it/s]3<1:15:12,  5.90it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.55it/s]3<1:18:34,  5.60it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.53it/s]4<1:19:32,  5.49it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.64it/s]3<1:17:56,  5.56it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.28it/s]4<1:12:32,  5.93it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.39it/s]0<1:23:42,  5.10it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.33it/s]1<1:10:24,  6.01it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.02it/s]6<1:14:22,  5.65it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.42it/s]1<1:23:14,  5.01it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.10it/s]9<1:19:19,  5.21it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.71it/s]4<1:14:30,  5.50it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.58it/s]0<1:13:34,  5.53it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.35it/s]5<1:24:47,  4.76it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.72it/s]4<1:19:30,  5.03it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.16it/s]1<1:10:14,  5.65it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.88it/s]6<1:19:11,  4.97it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.71it/s]3<1:07:48,  5.75it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.29it/s]8<1:13:02,  5.29it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.78it/s]9<1:07:33,  5.67it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.29it/s]4<1:10:08,  5.42it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.32it/s]8<1:05:30,  5.75it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.91it/s]3<1:02:23,  5.98it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.92it/s]8<1:08:50,  5.37it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.70it/s]3<1:05:54,  5.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.01it/s]9<59:20,  6.12it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.17it/s]4<1:03:02,  5.71it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.09it/s]0<1:00:29,  5.90it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.16it/s]5<1:04:11,  5.50it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.62it/s]0<1:07:26,  5.19it/s]
# 100%|██████████| 1000/1000 [00:27<00:00, 36.97it/s]5<1:08:20,  5.07it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.04it/s]3<1:02:59,  5.45it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.37it/s]9<1:01:39,  5.51it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.43it/s]3<1:06:29,  5.06it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 37.71it/s]0<57:37,  5.79it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.36it/s]7<58:48,  5.61it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.94it/s]2<1:08:22,  4.78it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 38.68it/s]7<1:03:48,  5.07it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.65it/s]4<55:05,  5.81it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.30it/s]8<1:07:15,  4.71it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.75it/s]4<1:16:41,  4.09it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.62it/s]7<54:57,  5.64it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.48it/s]2<1:03:53,  4.80it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.18it/s]7<51:44,  5.86it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.60it/s]2<55:03,  5.45it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.65it/s]7<56:56,  5.21it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.63it/s]2<53:36,  5.47it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.71it/s]7<53:28,  5.42it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.38it/s]1<57:28,  4.99it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.79it/s]4<56:31,  5.01it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.04it/s]9<51:26,  5.44it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.35it/s]8<54:20,  5.09it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.38it/s]8<51:13,  5.34it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.31it/s]4<56:22,  4.79it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.43it/s]4<49:45,  5.36it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.55it/s]5<54:17,  4.85it/s]
# 100%|██████████| 1000/1000 [00:28<00:00, 34.65it/s]5<43:23,  5.99it/s]
# 100%|██████████| 1000/1000 [00:28<00:00, 34.78it/s]3<42:36,  6.02it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 38.49it/s]2<47:46,  5.30it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.19it/s]9<42:08,  5.93it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.61it/s]3<46:58,  5.25it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.07it/s]8<44:08,  5.51it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.55it/s]4<47:50,  5.02it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.60it/s]0<40:22,  5.86it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.63it/s]9<41:59,  5.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.32it/s]0<39:02,  5.89it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.49it/s]5<39:59,  5.67it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.29it/s]5<45:03,  4.96it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.30it/s]1<40:11,  5.47it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.44it/s]4<32:22,  6.69it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 38.38it/s]5<38:25,  5.55it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.26it/s]2<41:55,  5.01it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.47it/s]6<34:15,  6.03it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.45it/s]0<37:24,  5.44it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.51it/s]9<39:04,  5.12it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.42it/s]9<32:51,  5.98it/s]
# 100%|██████████| 1000/1000 [00:28<00:00, 35.37it/s]0<34:11,  5.65it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.71it/s]8<34:44,  5.47it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.49it/s]8<40:12,  4.64it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.19it/s]7<30:53,  5.94it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.70it/s]2<33:00,  5.45it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.78it/s]1<34:57,  5.05it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.82it/s]6<34:33,  5.02it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.10it/s]1<34:25,  4.94it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.07it/s]6<25:58,  6.42it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.14it/s]1<41:56,  3.89it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.33it/s]5<28:57,  5.52it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.90it/s]1<28:04,  5.58it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.44it/s]5<26:03,  5.89it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.38it/s]0<26:19,  5.70it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.42it/s]4<27:47,  5.28it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.38it/s]8<31:08,  4.60it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.32it/s]2<24:05,  5.81it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.39it/s]6<26:09,  5.22it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.32it/s]1<24:02,  5.55it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.38it/s]5<24:53,  5.22it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.23it/s]0<23:13,  5.46it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.34it/s]4<22:26,  5.50it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.83it/s]9<23:35,  5.08it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.81it/s]3<20:59,  5.56it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.97it/s]4<22:38,  5.00it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.21it/s]8<19:53,  5.53it/s]
# 100%|██████████| 1000/1000 [00:26<00:00, 38.16it/s]9<19:06,  5.58it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.44it/s]7<22:09,  4.66it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.40it/s]8<18:07,  5.52it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.52it/s]3<15:48,  6.12it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.52it/s]4<18:45,  4.98it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.65it/s]4<15:37,  5.76it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.52it/s]4<14:56,  5.80it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.49it/s]3<14:53,  5.59it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.66it/s]4<14:32,  5.50it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.98it/s]4<13:37,  5.63it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.61it/s]3<12:54,  5.68it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.62it/s]2<13:13,  5.29it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.47it/s]2<10:48,  6.17it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.14it/s]6<12:13,  5.18it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 41.52it/s]1<11:19,  5.30it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.48it/s]5<10:30,  5.40it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.08it/s]1<09:55,  5.37it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.26it/s]7<09:15,  5.41it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.24it/s]8<09:16,  5.03it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.74it/s]7<08:10,  5.30it/s]
# 100%|██████████| 1000/1000 [00:25<00:00, 39.11it/s]1<06:37,  6.04it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.04it/s]7<05:57,  6.16it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.49it/s]8<05:52,  5.67it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.61it/s]2<04:36,  6.51it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.87it/s]6<04:53,  5.45it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.54it/s]2<04:52,  4.78it/s]
# 100%|██████████| 1000/1000 [00:24<00:00, 40.87it/s]7<03:59,  5.02it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.00it/s]1<02:54,  5.73it/s]
# 100%|██████████| 1000/1000 [00:29<00:00, 33.84it/s]0<02:28,  5.39it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.09it/s]0<01:32,  6.52it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 32.98it/s]1<01:19,  5.05it/s]
# 100%|██████████| 1000/1000 [00:30<00:00, 33.17it/s]1<00:31,  6.36it/s]
# Loss: 0.0126: 100%|██████████| 100000/100000 [9:40:11<00:00,  2.87it/s]

# %% [markdown]
# # Sampling

# %%
def main(args):
    save_dir = Path(args.save_dir)
    save_dir.mkdir(exist_ok=True, parents=True)

    device = f"cuda:{args.gpu}"

    ddpm = DiffusionModule(None, None)
    ddpm.load(args.ckpt_path)
    ddpm.eval()
    ddpm = ddpm.to(device)

    num_train_timesteps = ddpm.var_scheduler.num_train_timesteps
    ddpm.var_scheduler = DDPMScheduler(
        num_train_timesteps,
        beta_1=1e-4,
        beta_T=0.02,
        mode="linear",
    ).to(device)

    total_num_samples = 500
    num_batches = int(np.ceil(total_num_samples / args.batch_size))

    for i in range(num_batches):
        sidx = i * args.batch_size
        eidx = min(sidx + args.batch_size, total_num_samples)
        B = eidx - sidx

        if args.use_cfg:  # Enable CFG sampling
            assert ddpm.network.use_cfg, f"The model was not trained to support CFG."
            samples = ddpm.sample(
                B,
                class_label=torch.randint(1, 4, (B,)),
                guidance_scale=args.cfg_scale,
            )
        else:
            samples = ddpm.sample(B)

        pil_images = tensor_to_pil_image(samples)

        for j, img in zip(range(sidx, eidx), pil_images):
            img.save(save_dir / f"{j}.png")
            print(f"Saved the {j}-th image.")

args={
    "batch_size": 64,
    "gpu": 0,
    "ckpt_path": "results/diffusion-ddpm-01-01-193058/last.ckpt",
    "save_dir": "output_imgs/",
    # "use_cfg": "store_true",
    # "cfg_scale": 7.5,
    "sample_method": "ddpm"
}
args = DotMap(args)
main(args)

# if __name__ == "__main__":
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--batch_size", type=int, default=64)
#     parser.add_argument("--gpu", type=int, default=0)
#     parser.add_argument("--ckpt_path", type=str)
#     parser.add_argument("--save_dir", type=str)
#     parser.add_argument("--use_cfg", action="store_true")
#     parser.add_argument("--sample_method", type=str, default="ddpm")
#     parser.add_argument("--cfg_scale", type=float, default=7.5)


    # args = parser.parse_args()
    # main(args)
# Out:
# /tmp/ipykernel_3185563/2569850328.py:85: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dic = torch.load(file_path, map_location="cpu")
# 100%|██████████| 1000/1000 [02:44<00:00,  6.09it/s]
# Saved the 0-th image.
# Saved the 1-th image.
# Saved the 2-th image.
# Saved the 3-th image.
# Saved the 4-th image.
# Saved the 5-th image.
# Saved the 6-th image.
# Saved the 7-th image.
# Saved the 8-th image.
# Saved the 9-th image.
# Saved the 10-th image.
# Saved the 11-th image.
# Saved the 12-th image.
# Saved the 13-th image.
# Saved the 14-th image.
# Saved the 15-th image.
# Saved the 16-th image.
# Saved the 17-th image.
# Saved the 18-th image.
# Saved the 19-th image.
# Saved the 20-th image.
# Saved the 21-th image.
# Saved the 22-th image.
# Saved the 23-th image.
# Saved the 24-th image.
# Saved the 25-th image.
# Saved the 26-th image.
# Saved the 27-th image.
# Saved the 28-th image.
# Saved the 29-th image.
# Saved the 30-th image.
# Saved the 31-th image.
# Saved the 32-th image.
# Saved the 33-th image.
# Saved the 34-th image.
# Saved the 35-th image.
# Saved the 36-th image.
# Saved the 37-th image.
# Saved the 38-th image.
# Saved the 39-th image.
# Saved the 40-th image.
# Saved the 41-th image.
# Saved the 42-th image.
# Saved the 43-th image.
# Saved the 44-th image.
# Saved the 45-th image.
# Saved the 46-th image.
# Saved the 47-th image.
# Saved the 48-th image.
# Saved the 49-th image.
# Saved the 50-th image.
# Saved the 51-th image.
# Saved the 52-th image.
# Saved the 53-th image.
# Saved the 54-th image.
# Saved the 55-th image.
# Saved the 56-th image.
# Saved the 57-th image.
# Saved the 58-th image.
# Saved the 59-th image.
# Saved the 60-th image.
# Saved the 61-th image.
# Saved the 62-th image.
# Saved the 63-th image.
# 100%|██████████| 1000/1000 [03:50<00:00,  4.33it/s]
# Saved the 64-th image.
# Saved the 65-th image.
# Saved the 66-th image.
# Saved the 67-th image.
# Saved the 68-th image.
# Saved the 69-th image.
# Saved the 70-th image.
# Saved the 71-th image.
# Saved the 72-th image.
# Saved the 73-th image.
# Saved the 74-th image.
# Saved the 75-th image.
# Saved the 76-th image.
# Saved the 77-th image.
# Saved the 78-th image.
# Saved the 79-th image.
# Saved the 80-th image.
# Saved the 81-th image.
# Saved the 82-th image.
# Saved the 83-th image.
# Saved the 84-th image.
# Saved the 85-th image.
# Saved the 86-th image.
# Saved the 87-th image.
# Saved the 88-th image.
# Saved the 89-th image.
# Saved the 90-th image.
# Saved the 91-th image.
# Saved the 92-th image.
# Saved the 93-th image.
# Saved the 94-th image.
# Saved the 95-th image.
# Saved the 96-th image.
# Saved the 97-th image.
# Saved the 98-th image.
# Saved the 99-th image.
# Saved the 100-th image.
# Saved the 101-th image.
# Saved the 102-th image.
# Saved the 103-th image.
# Saved the 104-th image.
# Saved the 105-th image.
# Saved the 106-th image.
# Saved the 107-th image.
# Saved the 108-th image.
# Saved the 109-th image.
# Saved the 110-th image.
# Saved the 111-th image.
# Saved the 112-th image.
# Saved the 113-th image.
# Saved the 114-th image.
# Saved the 115-th image.
# Saved the 116-th image.
# Saved the 117-th image.
# Saved the 118-th image.
# Saved the 119-th image.
# Saved the 120-th image.
# Saved the 121-th image.
# Saved the 122-th image.
# Saved the 123-th image.
# Saved the 124-th image.
# Saved the 125-th image.
# Saved the 126-th image.
# Saved the 127-th image.
# 100%|██████████| 1000/1000 [03:52<00:00,  4.30it/s]
# Saved the 128-th image.
# Saved the 129-th image.
# Saved the 130-th image.
# Saved the 131-th image.
# Saved the 132-th image.
# Saved the 133-th image.
# Saved the 134-th image.
# Saved the 135-th image.
# Saved the 136-th image.
# Saved the 137-th image.
# Saved the 138-th image.
# Saved the 139-th image.
# Saved the 140-th image.
# Saved the 141-th image.
# Saved the 142-th image.
# Saved the 143-th image.
# Saved the 144-th image.
# Saved the 145-th image.
# Saved the 146-th image.
# Saved the 147-th image.
# Saved the 148-th image.
# Saved the 149-th image.
# Saved the 150-th image.
# Saved the 151-th image.
# Saved the 152-th image.
# Saved the 153-th image.
# Saved the 154-th image.
# Saved the 155-th image.
# Saved the 156-th image.
# Saved the 157-th image.
# Saved the 158-th image.
# Saved the 159-th image.
# Saved the 160-th image.
# Saved the 161-th image.
# Saved the 162-th image.
# Saved the 163-th image.
# Saved the 164-th image.
# Saved the 165-th image.
# Saved the 166-th image.
# Saved the 167-th image.
# Saved the 168-th image.
# Saved the 169-th image.
# Saved the 170-th image.
# Saved the 171-th image.
# Saved the 172-th image.
# Saved the 173-th image.
# Saved the 174-th image.
# Saved the 175-th image.
# Saved the 176-th image.
# Saved the 177-th image.
# Saved the 178-th image.
# Saved the 179-th image.
# Saved the 180-th image.
# Saved the 181-th image.
# Saved the 182-th image.
# Saved the 183-th image.
# Saved the 184-th image.
# Saved the 185-th image.
# Saved the 186-th image.
# Saved the 187-th image.
# Saved the 188-th image.
# Saved the 189-th image.
# Saved the 190-th image.
# Saved the 191-th image.
# 100%|██████████| 1000/1000 [03:54<00:00,  4.26it/s]
# Saved the 192-th image.
# Saved the 193-th image.
# Saved the 194-th image.
# Saved the 195-th image.
# Saved the 196-th image.
# Saved the 197-th image.
# Saved the 198-th image.
# Saved the 199-th image.
# Saved the 200-th image.
# Saved the 201-th image.
# Saved the 202-th image.
# Saved the 203-th image.
# Saved the 204-th image.
# Saved the 205-th image.
# Saved the 206-th image.
# Saved the 207-th image.
# Saved the 208-th image.
# Saved the 209-th image.
# Saved the 210-th image.
# Saved the 211-th image.
# Saved the 212-th image.
# Saved the 213-th image.
# Saved the 214-th image.
# Saved the 215-th image.
# Saved the 216-th image.
# Saved the 217-th image.
# Saved the 218-th image.
# Saved the 219-th image.
# Saved the 220-th image.
# Saved the 221-th image.
# Saved the 222-th image.
# Saved the 223-th image.
# Saved the 224-th image.
# Saved the 225-th image.
# Saved the 226-th image.
# Saved the 227-th image.
# Saved the 228-th image.
# Saved the 229-th image.
# Saved the 230-th image.
# Saved the 231-th image.
# Saved the 232-th image.
# Saved the 233-th image.
# Saved the 234-th image.
# Saved the 235-th image.
# Saved the 236-th image.
# Saved the 237-th image.
# Saved the 238-th image.
# Saved the 239-th image.
# Saved the 240-th image.
# Saved the 241-th image.
# Saved the 242-th image.
# Saved the 243-th image.
# Saved the 244-th image.
# Saved the 245-th image.
# Saved the 246-th image.
# Saved the 247-th image.
# Saved the 248-th image.
# Saved the 249-th image.
# Saved the 250-th image.
# Saved the 251-th image.
# Saved the 252-th image.
# Saved the 253-th image.
# Saved the 254-th image.
# Saved the 255-th image.
# 100%|██████████| 1000/1000 [03:55<00:00,  4.24it/s]
# Saved the 256-th image.
# Saved the 257-th image.
# Saved the 258-th image.
# Saved the 259-th image.
# Saved the 260-th image.
# Saved the 261-th image.
# Saved the 262-th image.
# Saved the 263-th image.
# Saved the 264-th image.
# Saved the 265-th image.
# Saved the 266-th image.
# Saved the 267-th image.
# Saved the 268-th image.
# Saved the 269-th image.
# Saved the 270-th image.
# Saved the 271-th image.
# Saved the 272-th image.
# Saved the 273-th image.
# Saved the 274-th image.
# Saved the 275-th image.
# Saved the 276-th image.
# Saved the 277-th image.
# Saved the 278-th image.
# Saved the 279-th image.
# Saved the 280-th image.
# Saved the 281-th image.
# Saved the 282-th image.
# Saved the 283-th image.
# Saved the 284-th image.
# Saved the 285-th image.
# Saved the 286-th image.
# Saved the 287-th image.
# Saved the 288-th image.
# Saved the 289-th image.
# Saved the 290-th image.
# Saved the 291-th image.
# Saved the 292-th image.
# Saved the 293-th image.
# Saved the 294-th image.
# Saved the 295-th image.
# Saved the 296-th image.
# Saved the 297-th image.
# Saved the 298-th image.
# Saved the 299-th image.
# Saved the 300-th image.
# Saved the 301-th image.
# Saved the 302-th image.
# Saved the 303-th image.
# Saved the 304-th image.
# Saved the 305-th image.
# Saved the 306-th image.
# Saved the 307-th image.
# Saved the 308-th image.
# Saved the 309-th image.
# Saved the 310-th image.
# Saved the 311-th image.
# Saved the 312-th image.
# Saved the 313-th image.
# Saved the 314-th image.
# Saved the 315-th image.
# Saved the 316-th image.
# Saved the 317-th image.
# Saved the 318-th image.
# Saved the 319-th image.
# 100%|██████████| 1000/1000 [03:54<00:00,  4.27it/s]
# Saved the 320-th image.
# Saved the 321-th image.
# Saved the 322-th image.
# Saved the 323-th image.
# Saved the 324-th image.
# Saved the 325-th image.
# Saved the 326-th image.
# Saved the 327-th image.
# Saved the 328-th image.
# Saved the 329-th image.
# Saved the 330-th image.
# Saved the 331-th image.
# Saved the 332-th image.
# Saved the 333-th image.
# Saved the 334-th image.
# Saved the 335-th image.
# Saved the 336-th image.
# Saved the 337-th image.
# Saved the 338-th image.
# Saved the 339-th image.
# Saved the 340-th image.
# Saved the 341-th image.
# Saved the 342-th image.
# Saved the 343-th image.
# Saved the 344-th image.
# Saved the 345-th image.
# Saved the 346-th image.
# Saved the 347-th image.
# Saved the 348-th image.
# Saved the 349-th image.
# Saved the 350-th image.
# Saved the 351-th image.
# Saved the 352-th image.
# Saved the 353-th image.
# Saved the 354-th image.
# Saved the 355-th image.
# Saved the 356-th image.
# Saved the 357-th image.
# Saved the 358-th image.
# Saved the 359-th image.
# Saved the 360-th image.
# Saved the 361-th image.
# Saved the 362-th image.
# Saved the 363-th image.
# Saved the 364-th image.
# Saved the 365-th image.
# Saved the 366-th image.
# Saved the 367-th image.
# Saved the 368-th image.
# Saved the 369-th image.
# Saved the 370-th image.
# Saved the 371-th image.
# Saved the 372-th image.
# Saved the 373-th image.
# Saved the 374-th image.
# Saved the 375-th image.
# Saved the 376-th image.
# Saved the 377-th image.
# Saved the 378-th image.
# Saved the 379-th image.
# Saved the 380-th image.
# Saved the 381-th image.
# Saved the 382-th image.
# Saved the 383-th image.
# 100%|██████████| 1000/1000 [03:56<00:00,  4.23it/s]
# Saved the 384-th image.
# Saved the 385-th image.
# Saved the 386-th image.
# Saved the 387-th image.
# Saved the 388-th image.
# Saved the 389-th image.
# Saved the 390-th image.
# Saved the 391-th image.
# Saved the 392-th image.
# Saved the 393-th image.
# Saved the 394-th image.
# Saved the 395-th image.
# Saved the 396-th image.
# Saved the 397-th image.
# Saved the 398-th image.
# Saved the 399-th image.
# Saved the 400-th image.
# Saved the 401-th image.
# Saved the 402-th image.
# Saved the 403-th image.
# Saved the 404-th image.
# Saved the 405-th image.
# Saved the 406-th image.
# Saved the 407-th image.
# Saved the 408-th image.
# Saved the 409-th image.
# Saved the 410-th image.
# Saved the 411-th image.
# Saved the 412-th image.
# Saved the 413-th image.
# Saved the 414-th image.
# Saved the 415-th image.
# Saved the 416-th image.
# Saved the 417-th image.
# Saved the 418-th image.
# Saved the 419-th image.
# Saved the 420-th image.
# Saved the 421-th image.
# Saved the 422-th image.
# Saved the 423-th image.
# Saved the 424-th image.
# Saved the 425-th image.
# Saved the 426-th image.
# Saved the 427-th image.
# Saved the 428-th image.
# Saved the 429-th image.
# Saved the 430-th image.
# Saved the 431-th image.
# Saved the 432-th image.
# Saved the 433-th image.
# Saved the 434-th image.
# Saved the 435-th image.
# Saved the 436-th image.
# Saved the 437-th image.
# Saved the 438-th image.
# Saved the 439-th image.
# Saved the 440-th image.
# Saved the 441-th image.
# Saved the 442-th image.
# Saved the 443-th image.
# Saved the 444-th image.
# Saved the 445-th image.
# Saved the 446-th image.
# Saved the 447-th image.
# 100%|██████████| 1000/1000 [03:10<00:00,  5.26it/s]
# Saved the 448-th image.
# Saved the 449-th image.
# Saved the 450-th image.
# Saved the 451-th image.
# Saved the 452-th image.
# Saved the 453-th image.
# Saved the 454-th image.
# Saved the 455-th image.
# Saved the 456-th image.
# Saved the 457-th image.
# Saved the 458-th image.
# Saved the 459-th image.
# Saved the 460-th image.
# Saved the 461-th image.
# Saved the 462-th image.
# Saved the 463-th image.
# Saved the 464-th image.
# Saved the 465-th image.
# Saved the 466-th image.
# Saved the 467-th image.
# Saved the 468-th image.
# Saved the 469-th image.
# Saved the 470-th image.
# Saved the 471-th image.
# Saved the 472-th image.
# Saved the 473-th image.
# Saved the 474-th image.
# Saved the 475-th image.
# Saved the 476-th image.
# Saved the 477-th image.
# Saved the 478-th image.
# Saved the 479-th image.
# Saved the 480-th image.
# Saved the 481-th image.
# Saved the 482-th image.
# Saved the 483-th image.
# Saved the 484-th image.
# Saved the 485-th image.
# Saved the 486-th image.
# Saved the 487-th image.
# Saved the 488-th image.
# Saved the 489-th image.
# Saved the 490-th image.
# Saved the 491-th image.
# Saved the 492-th image.
# Saved the 493-th image.
# Saved the 494-th image.
# Saved the 495-th image.
# Saved the 496-th image.
# Saved the 497-th image.
# Saved the 498-th image.
# Saved the 499-th image.

# %% [markdown]
# # Inception

# %%
"""
StarGAN v2
Copyright (c) 2020-present NAVER Corp.

This work is licensed under the Creative Commons Attribution-NonCommercial
4.0 International License. To view a copy of this license, visit
http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.
"""


class InceptionV3(nn.Module):
    def __init__(self, for_train):
        super().__init__()
        self.for_train = for_train

        inception = models.inception_v3(pretrained=False)
        self.block1 = nn.Sequential(
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.block2 = nn.Sequential(
            inception.Conv2d_3b_1x1,
            inception.Conv2d_4a_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.block3 = nn.Sequential(
            inception.Mixed_5b,
            inception.Mixed_5c,
            inception.Mixed_5d,
            inception.Mixed_6a,
            inception.Mixed_6b,
            inception.Mixed_6c,
            inception.Mixed_6d,
            inception.Mixed_6e,
        )
        self.block4 = nn.Sequential(
            inception.Mixed_7a,
            inception.Mixed_7b,
            inception.Mixed_7c,
            nn.AdaptiveAvgPool2d(output_size=(1, 1)),
        )

        self.final_fc = nn.Linear(2048, 3)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = x.view(x.size(0), -1)
        if self.for_train:
            return self.final_fc(x)
        else:
            return x

# %% [markdown]
# # FID

# %%
try:
    from tqdm import tqdm
except ImportError:
    def tqdm(x):
        return x

class ImagePathDataset(torch.utils.data.Dataset):
    def __init__(self, files, img_size):
        self.files = files
        self.img_size = img_size
        self.transforms = transforms.Compose(
            [
                transforms.Resize((img_size, img_size)),
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            ]
        )

    def __len__(self):
        return len(self.files)

    def __getitem__(self, i):
        path = self.files[i]
        img = Image.open(path).convert("RGB")
        if self.transforms is not None:
            img = self.transforms(img)
        return img

# %%
def get_eval_loader(path, img_size, batch_size):
    def listdir(dname):
        fnames = list(
            chain(
                *[
                    list(Path(dname).rglob("*." + ext))
                    for ext in ["png", "jpg", "jpeg", "JPG"]
                ]
            )
        )
        return fnames

    files = listdir(path)
    ds = ImagePathDataset(files, img_size)
    dl = torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=False, drop_last=False, num_workers=4)
    return dl

def frechet_distance(mu, cov, mu2, cov2):
    cc, _ = linalg.sqrtm(np.dot(cov, cov2), disp=False)
    dist = np.sum((mu - mu2) ** 2) + np.trace(cov + cov2 - 2 * cc)
    return np.real(dist)

# %%
@torch.no_grad()
def calculate_fid_given_paths(paths, img_size=256, batch_size=50):
    print("Calculating FID given paths %s and %s..." % (paths[0], paths[1]))
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    inception = InceptionV3(for_train=False)
    # current_dir = Path(os.path.realpath(__file__)).parent
    # ckpt = torch.load(current_dir / "afhq_inception_v3.ckpt", map_location="cpu")
    ckpt = torch.load("afhq_inception_v3.ckpt", map_location="cpu")
    inception.load_state_dict(ckpt)
    inception = inception.eval().to(device)
    loaders = [get_eval_loader(path, img_size, batch_size) for path in paths]

    mu, cov = [], []
    for loader in loaders:
        actvs = []
        for x in tqdm(loader, total=len(loader)):
            actv = inception(x.to(device))
            actvs.append(actv)
        actvs = torch.cat(actvs, dim=0).cpu().detach().numpy()
        mu.append(np.mean(actvs, axis=0))
        cov.append(np.cov(actvs, rowvar=False))
    fid_value = frechet_distance(mu[0], cov[0], mu[1], cov[1])
    return fid_value

if __name__ == "__main__":
    # python measure_fid /path/to/dir1 /path/to/dir2
    paths = ["data/afhq/eval/", "output_imgs/"]
    fid_value = calculate_fid_given_paths(paths, img_size=256, batch_size=64)
    print("FID:", fid_value)
# Out:
# Calculating FID given paths data/afhq/eval/ and output_imgs/...
# /tmp/ipykernel_3185563/780988446.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load("afhq_inception_v3.ckpt", map_location="cpu")
# 100%|██████████| 24/24 [00:01<00:00, 14.76it/s]
# 100%|██████████| 8/8 [00:00<00:00,  8.85it/s]
# FID: 5.085153700686984

# %%
from IPython.display import Image, display

# Display the image
display(Image(filename="output_imgs/190.png"))
display(Image(filename="data/afhq/eval/flickr_cat_000056.jpg"))
